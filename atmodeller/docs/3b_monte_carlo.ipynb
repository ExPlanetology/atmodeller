# %% [markdown]
# # atmodeller
#
# ## Tutorial 3b: Monte Carlo experiment
#
# We can devise a simple Monte Carlo (MC) approach to sample the probable atmospheres that can arise for different planetary conditions.

# %%
from atmodeller import debug_logger
from atmodeller.interior_atmosphere import InteriorAtmosphereSystem, Planet, Species
from atmodeller.constraints import MassConstraint, IronWustiteBufferConstraintHirschmann, SystemConstraints
from atmodeller.interfaces import GasSpecies
from atmodeller.solubilities import PeridotiteH2O, BasaltDixonCO2, BasaltLibourelN2
from atmodeller.utilities import earth_oceans_to_kg
from atmodeller.initial_condition import InitialConditionRegressor
import numpy as np
import logging

# %% [markdown]
# For production runs, make sure to set the logger to INFO or higher (i.e. WARNING, ERROR, or CRITICAL). Otherwise you will find that your MC runs slower just because of writing the output to the logger.

# %%
logger = debug_logger()
logger.setLevel(logging.INFO)

# %% [markdown]
# We now create the species that we are interested in. Note that we comment out CO2 in this case.

# %%
species: Species = Species()
species.append(GasSpecies(formula='H2O', solubility=PeridotiteH2O()))
species.append(GasSpecies(formula='H2'))
species.append(GasSpecies(formula='O2'))
species.append(GasSpecies(formula='CO'))
#species.append(GasSpecies(formula='CO2', solubility=BasaltDixonCO2()))
species.append(GasSpecies(formula='N2', solubility=BasaltLibourelN2()))
species
# Out:
# [13:28:22 - atmodeller.interfaces          - INFO     ] - Creating GasSpecies H2O using thermodynamic data in JANAF (JANAF name = H2O)
# [13:28:22 - atmodeller.interfaces          - INFO     ] - Creating GasSpecies H2 using thermodynamic data in JANAF (JANAF name = H2)
# [13:28:22 - atmodeller.interfaces          - INFO     ] - Creating GasSpecies O2 using thermodynamic data in JANAF (JANAF name = O2)
# [13:28:22 - atmodeller.interfaces          - INFO     ] - Creating GasSpecies CO using thermodynamic data in JANAF (JANAF name = CO)
# [13:28:22 - atmodeller.interfaces          - INFO     ] - Creating GasSpecies N2 using thermodynamic data in JANAF (JANAF name = N2)
# Species([GasSpecies(formula='H2O', thermodynamic_dataset=<atmodeller.interfaces.ThermodynamicDatasetJANAF object at 0x11efbc0d0>, name_in_dataset='H2O', _formula=Formula('H2O'), _thermodynamic_data=ThermodynamicDatasetJANAF.ThermodynamicDataForSpecies(species=..., data_source='JANAF', data=<thermochem.janaf.JanafPhase object at 0x11effd550>), _output=None, solubility=<atmodeller.solubilities.PeridotiteH2O object at 0x11efb3650>, solid_melt_distribution_coefficient=0, eos=IdealGas(critical_temperature=1, critical_pressure=1, standard_state_pressure=1)),
#          GasSpecies(formula='H2', thermodynamic_dataset=<atmodeller.interfaces.ThermodynamicDatasetJANAF object at 0x11efb3ed0>, name_in_dataset='H2', _formula=Formula('H2'), _thermodynamic_data=ThermodynamicDatasetJANAF.ThermodynamicDataForSpecies(species=..., data_source='JANAF', data=<thermochem.janaf.JanafPhase object at 0x11f06e590>), _output=None, solubility=<atmodeller.interfaces.NoSolubility object at 0x11efb3790>, solid_melt_distribution_coefficient=0, eos=IdealGas(critical_temperature=1, critical_pressure=1, standard_state_pressure=1)),
#          GasSpecies(formula='O2', thermodynamic_dataset=<atmodeller.interfaces.ThermodynamicDatasetJANAF object at 0x11efb3e90>, name_in_dataset='O2', _formula=Formula('O2'), _thermodynamic_data=ThermodynamicDatasetJANAF.ThermodynamicDataForSpecies(species=..., data_source='JANAF', data=<thermochem.janaf.JanafPhase object at 0x11f0da190>), _output=None, solubility=<atmodeller.interfaces.NoSolubility object at 0x11f0a9f50>, solid_melt_distribution_coefficient=0, eos=IdealGas(critical_temperature=1, critical_pressure=1, standard_state_pressure=1)),
#          GasSpecies(formula='CO', thermodynamic_dataset=<atmodeller.interfaces.ThermodynamicDatasetJANAF object at 0x11f0da590>, name_in_dataset='CO', _formula=Formula('CO'), _thermodynamic_data=ThermodynamicDatasetJANAF.ThermodynamicDataForSpecies(species=..., data_source='JANAF', data=<thermochem.janaf.JanafPhase object at 0x11f14a710>), _output=None, solubility=<atmodeller.interfaces.NoSolubility object at 0x11f0da2d0>, solid_melt_distribution_coefficient=0, eos=IdealGas(critical_temperature=1, critical_pressure=1, standard_state_pressure=1)),
#          GasSpecies(formula='N2', thermodynamic_dataset=<atmodeller.interfaces.ThermodynamicDatasetJANAF object at 0x11f14a850>, name_in_dataset='N2', _formula=Formula('N2'), _thermodynamic_data=ThermodynamicDatasetJANAF.ThermodynamicDataForSpecies(species=..., data_source='JANAF', data=<thermochem.janaf.JanafPhase object at 0x11f194490>), _output=None, solubility=<atmodeller.solubilities.BasaltLibourelN2 object at 0x11f18a0d0>, solid_melt_distribution_coefficient=0, eos=IdealGas(critical_temperature=1, critical_pressure=1, standard_state_pressure=1))])

# %% [markdown]
# Now create a planet. We recall that we can sample different planetary properties by updating the attributes of this object, even though in this tutorial we don't do this.

# %%
planet: Planet = Planet()
# Out:
# [13:28:26 - atmodeller.interior_atmosphere - INFO     ] - Creating a new planet
# [13:28:26 - atmodeller.interior_atmosphere - INFO     ] - Mantle mass (kg) = 4208261222595110885130240.000000
# [13:28:26 - atmodeller.interior_atmosphere - INFO     ] - Mantle melt fraction = 1.000000
# [13:28:26 - atmodeller.interior_atmosphere - INFO     ] - Core mass fraction = 0.295335
# [13:28:26 - atmodeller.interior_atmosphere - INFO     ] - Planetary radius (m) = 6371000.000000
# [13:28:26 - atmodeller.interior_atmosphere - INFO     ] - Planetary mass (kg) = 5972000000000000327155712.000000
# [13:28:26 - atmodeller.interior_atmosphere - INFO     ] - Surface temperature (K) = 2000.000000
# [13:28:26 - atmodeller.interior_atmosphere - INFO     ] - Surface gravity (m/s^2) = 9.819973
# [13:28:26 - atmodeller.interior_atmosphere - INFO     ] - Melt Composition = None

# %% [markdown]
# Now set up the main driver of the Monte Carlo (MC) approach. This establishes the ranges over which we sample certain properties.

# %%
def monte_carlo(interior_atmosphere: InteriorAtmosphereSystem, number_of_realisations:int=100):
    """Monte Carlo driver
    
    Args:
        interior_atmosphere: An interior-atmosphere system
        number_of_realisation: Number of simulations to perform
    """

    # Parameters are normally distributed between bounds.
    number_ocean_moles = np.random.uniform(1, 10, number_of_realisations)
    ch_ratios = np.random.uniform(0.1, 1, number_of_realisations)
    fo2_shifts = np.random.uniform(-4, 4, number_of_realisations)

    # ppmw of Nitrogen in the mantle. 2.8 is the mantle value of N.
    N_ppmw = 2.8

    # The nitrogen mass is constant
    mass_N = N_ppmw * 1.0e-6 * planet.mantle_mass

    for realisation in range(number_of_realisations):

        mass_H = earth_oceans_to_kg(number_ocean_moles[realisation])
        mass_C = ch_ratios[realisation] * mass_H
        constraints = SystemConstraints([
            MassConstraint(species="H", value=mass_H),
            MassConstraint(species="C", value=mass_C),
            MassConstraint(species="N", value=mass_N),
            IronWustiteBufferConstraintHirschmann(log10_shift=fo2_shifts[realisation])
        ])

        # Extra quantities to write to the output
        # For example, it's often helpful to have the constraints expressed in a more convenient
        # form for analysis and plotting.
        extra = {'fO2_shift': fo2_shifts[realisation], 'C/H ratio':ch_ratios[realisation],
            'Number of ocean moles':number_ocean_moles[realisation]}

        interior_atmosphere.solve(constraints, extra_output=extra, factor=0.1)

# %% [markdown]
# We can run the MC as follows. This may take a minute or two to run.

# %%
interior_atmosphere: InteriorAtmosphereSystem = InteriorAtmosphereSystem(species=species, planet=planet)
monte_carlo(interior_atmosphere)
# Out:
# [13:28:35 - atmodeller.initial_condition   - INFO     ] - Creating InitialConditionConstant
# [13:28:35 - atmodeller.interior_atmosphere - INFO     ] - Creating an interior-atmosphere system
# [13:28:35 - atmodeller.interior_atmosphere - INFO     ] - Creating a reaction network
# [13:28:35 - atmodeller.interior_atmosphere - INFO     ] - Species = ['H2O', 'H2', 'O2', 'CO', 'N2']
# [13:28:35 - atmodeller.interior_atmosphere - INFO     ] - Reactions =
# {0: '1.0 H2O = 1.0 H2 + 0.5 O2'}
# [13:28:35 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 0
# [13:28:37 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:37 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 1.009561953965116
# [13:28:37 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 235.77025255140236,
#  'H2': 308.3157860325377,
#  'H2O': 16.27070929555066,
#  'N2': 1.05959559229644,
#  'O2': 2.3211509283050356e-10}
# [13:28:37 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 1
# [13:28:37 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:37 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.8953474541720111
# [13:28:37 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 30.84208459186112,
#  'H2': 0.2099492717955027,
#  'H2O': 1.9735539073272808,
#  'N2': 2.108544086204441,
#  'O2': 7.364634092712993e-06}
# [13:28:37 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 2
# [13:28:38 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:38 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.7630987682144937
# [13:28:38 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 77.11365467912039,
#  'H2': 103.00392012378786,
#  'H2O': 4.2197187099440825,
#  'N2': 1.049719331383434,
#  'O2': 1.3987542797283953e-10}
# [13:28:38 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 3
# [13:28:38 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:38 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.6514832976342135
# [13:28:38 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 117.000877719666,
#  'H2': 35.831948587568384,
#  'H2O': 5.160094601123525,
#  'N2': 1.7022272746732667,
#  'O2': 1.7284483525326323e-09}
# [13:28:38 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 4
# [13:28:38 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:38 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.9860873841943832
# [13:28:38 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 104.5084239790098,
#  'H2': 347.52822497645224,
#  'H2O': 6.611659853643998,
#  'N2': 0.6456499563566972,
#  'O2': 3.016635051336871e-11}
# [13:28:38 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 5
# [13:28:39 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:39 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.6144759779697444
# [13:28:39 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 141.1946019877569,
#  'H2': 4.957316283702666,
#  'H2O': 10.343507615969711,
#  'N2': 2.053294419277449,
#  'O2': 3.628476815996236e-07}
# [13:28:39 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 6
# [13:28:39 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:39 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.8632622557194028
# [13:28:39 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 158.0951921164202,
#  'H2': 151.99309959054403,
#  'H2O': 17.186287471250775,
#  'N2': 1.2171035520107527,
#  'O2': 1.065610110954266e-09}
# [13:28:39 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 7
# [13:28:39 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:39 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 1.1964875604022556
# [13:28:39 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 15.181208566832607,
#  'H2': 0.08161085443747003,
#  'H2O': 0.30074098722965353,
#  'N2': 2.1400018855599745,
#  'O2': 1.1318042610535535e-06}
# [13:28:39 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 8
# [13:28:40 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:40 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.6898983241933698
# [13:28:40 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 184.13741591900194,
#  'H2': 21.971308410668236,
#  'H2O': 23.892549243398886,
#  'N2': 1.902900785541256,
#  'O2': 9.855872374796534e-08}
# [13:28:40 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 9
# [13:28:40 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:40 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.7910934359387758
# [13:28:40 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 301.6858895905459,
#  'H2': 43.174711769413406,
#  'H2O': 13.514763404243839,
#  'N2': 1.9025362098591139,
#  'O2': 8.166574580481834e-09}
# [13:28:40 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 10
# [13:28:41 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:41 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.7655380806557803
# [13:28:41 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 40.651905131728725,
#  'H2': 126.8372639903115,
#  'H2O': 18.401574126259945,
#  'N2': 0.7450640201086157,
#  'O2': 1.7542769316277753e-09}
# [13:28:41 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 11
# [13:28:41 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:41 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.6040078786663062
# [13:28:41 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 36.71121409875266,
#  'H2': 28.88307565432512,
#  'H2O': 1.903458746417318,
#  'N2': 1.319154527107104,
#  'O2': 3.6197784832122884e-10}
# [13:28:41 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 12
# [13:28:41 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:41 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.8550226778249093
# [13:28:41 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 296.32198783934945,
#  'H2': 87.73238964912431,
#  'H2O': 7.747764910546334,
#  'N2': 1.712535794525904,
#  'O2': 6.500022853245823e-10}
# [13:28:41 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 13
# [13:28:42 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:42 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.7909866963881693
# [13:28:42 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 45.757503911441574,
#  'H2': 146.11292112609473,
#  'H2O': 10.309834119821998,
#  'N2': 0.6988862023977616,
#  'O2': 4.1496172556615924e-10}
# [13:28:42 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 14
# [13:28:42 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:42 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.936440633170258
# [13:28:42 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 141.74718070403637,
#  'H2': 0.4622136544950333,
#  'H2O': 1.227222901734115,
#  'N2': 2.149002232796976,
#  'O2': 5.875479191785194e-07}
# [13:28:42 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 15
# [13:28:42 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:42 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.7490634496182085
# [13:28:42 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 33.0844754403239,
#  'H2': 28.52161668473584,
#  'H2O': 0.5866144069207094,
#  'N2': 1.2567826182730812,
#  'O2': 3.5256492479739546e-11}
# [13:28:42 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 16
# [13:28:43 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:43 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.9970154233764486
# [13:28:43 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 123.72115259496873,
#  'H2': 321.21352732154503,
#  'H2O': 3.5563475106151246,
#  'N2': 0.7207763906655781,
#  'O2': 1.0216512308892832e-11}
# [13:28:43 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 17
# [13:28:43 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:43 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.6239958188373915
# [13:28:43 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 59.36524016247366,
#  'H2': 4.8798622250784245,
#  'H2O': 1.3344528088564376,
#  'N2': 2.007407252762703,
#  'O2': 6.232657346695498e-09}
# [13:28:43 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 18
# [13:28:44 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:44 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 1.444723065195692
# [13:28:44 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 94.95425540155654,
#  'H2': 0.014972231590682644,
#  'H2O': 0.9373185446318741,
#  'N2': 2.1539847424084106,
#  'O2': 0.00032665046359246726}
# [13:28:44 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 19
# [13:28:44 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:44 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.9907134774669943
# [13:28:44 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 270.6096842323914,
#  'H2': 0.2886988007884236,
#  'H2O': 15.105441631222483,
#  'N2': 2.1208196372816315,
#  'O2': 0.00022817014927960003}
# [13:28:44 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 20
# [13:28:45 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:45 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.9735366070639673
# [13:28:45 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 18.38320816419134,
#  'H2': 296.6389960514701,
#  'H2O': 3.94127633686242,
#  'N2': 0.29578172635764544,
#  'O2': 1.4712931690262775e-11}
# [13:28:45 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 21
# [13:28:45 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:45 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 1.2873289861341966
# [13:28:45 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 40.78562187326195,
#  'H2': 0.03822669714396435,
#  'H2O': 0.5321722251386825,
#  'N2': 2.150634757436058,
#  'O2': 1.6152984979049353e-05}
# [13:28:45 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 22
# [13:28:45 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:45 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.7528473814831905
# [13:28:45 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 180.3727770031328,
#  'H2': 1.6181112206257224,
#  'H2O': 3.7731380792222953,
#  'N2': 2.13002323398609,
#  'O2': 4.5317984915015683e-07}
# [13:28:45 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 23
# [13:28:46 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:46 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 1.2985113987884713
# [13:28:46 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 63.033184843396036,
#  'H2': 0.0356895369350102,
#  'H2O': 0.6844944431337544,
#  'N2': 2.1526334953069113,
#  'O2': 3.065772748995408e-05}
# [13:28:46 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 24
# [13:28:46 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:46 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.7285400324993947
# [13:28:46 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 128.89166283154168,
#  'H2': 1.953623249330373,
#  'H2O': 2.079714273559287,
#  'N2': 2.1221787807295867,
#  'O2': 9.445123635174877e-08}
# [13:28:46 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 25
# [13:28:46 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:46 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.9237905956621664
# [13:28:46 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 24.24850758764083,
#  'H2': 0.21421018620742882,
#  'H2O': 1.156210052454312,
#  'N2': 2.115861278125931,
#  'O2': 2.4281481250447586e-06}
# [13:28:46 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 26
# [13:28:47 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:47 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.7712203547644775
# [13:28:47 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 367.7330873662039,
#  'H2': 5.752032062063759,
#  'H2O': 7.880546262267479,
#  'N2': 2.117402552659205,
#  'O2': 1.5644150367046667e-07}
# [13:28:47 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 27
# [13:28:47 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:47 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.6004061104102181
# [13:28:47 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 39.864135348009626,
#  'H2': 1.4036100106261822,
#  'H2O': 3.2247033647668055,
#  'N2': 2.0524554495300795,
#  'O2': 4.399147864500421e-07}
# [13:28:47 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 28
# [13:28:47 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:47 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.8066494370212844
# [13:28:47 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 59.67438857682571,
#  'H2': 138.8507548801638,
#  'H2O': 4.256366596674456,
#  'N2': 0.7955573137048152,
#  'O2': 7.831834369936435e-11}
# [13:28:47 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 29
# [13:28:48 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:48 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.8300736590347034
# [13:28:48 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 228.9872525636611,
#  'H2': 1.1229262054466254,
#  'H2O': 3.1885782596716603,
#  'N2': 2.1421940548828067,
#  'O2': 6.720067874418616e-07}
# [13:28:48 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 30
# [13:28:48 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:48 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.9637823633252894
# [13:28:48 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 262.4522920735975,
#  'H2': 223.25593639016395,
#  'H2O': 8.800757158883446,
#  'N2': 1.2618608398994857,
#  'O2': 1.2951377914906613e-10}
# [13:28:48 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 31
# [13:28:48 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:48 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 1.1900797287409295
# [13:28:48 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 289.74823732743886,
#  'H2': 0.07632439446817148,
#  'H2O': 7.693921494042177,
#  'N2': 2.141935502534593,
#  'O2': 0.000846936204887262}
# [13:28:48 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 32
# [13:28:49 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:49 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 1.0166783081733684
# [13:28:49 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 154.64611371763658,
#  'H2': 0.2226932208303344,
#  'H2O': 1.7365349194207655,
#  'N2': 2.1505713072902646,
#  'O2': 5.067981031188713e-06}
# [13:28:49 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 33
# [13:28:49 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:49 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.7577325817124857
# [13:28:49 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 340.9172835625384,
#  'H2': 6.657848689024144,
#  'H2O': 6.5225844970426365,
#  'N2': 2.111927466707213,
#  'O2': 7.999328249216783e-08}
# [13:28:49 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 34
# [13:28:50 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:50 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.9622051122610876
# [13:28:50 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 29.460457085238243,
#  'H2': 285.2788543262708,
#  'H2O': 3.39924177067449,
#  'N2': 0.363676435574481,
#  'O2': 1.1833327340332232e-11}
# [13:28:50 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 35
# [13:28:50 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:50 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.6678378768803068
# [13:28:50 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 207.49078626300107,
#  'H2': 7.428389829343444,
#  'H2O': 7.800723232058308,
#  'N2': 2.0723415989558553,
#  'O2': 9.190990088452853e-08}
# [13:28:50 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 36
# [13:28:50 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:50 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.7438406710001386
# [13:28:50 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 126.69794622123945,
#  'H2': 1.5058774479377475,
#  'H2O': 2.238783379148471,
#  'N2': 2.1270798432438545,
#  'O2': 1.8421577670906803e-07}
# [13:28:50 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 37
# [13:28:51 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:51 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.936575189963124
# [13:28:51 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 322.10731182779034,
#  'H2': 150.09153565668026,
#  'H2O': 18.220744864462556,
#  'N2': 1.5403912177476269,
#  'O2': 1.228292454399833e-09}
# [13:28:51 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 38
# [13:28:51 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:51 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.5573506783371538
# [13:28:51 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 87.74506392695376,
#  'H2': 4.9628775343602465,
#  'H2O': 18.32354378018209,
#  'N2': 1.9572187290284544,
#  'O2': 1.136144984018947e-06}
# [13:28:51 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 39
# [13:28:52 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:52 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 1.0285144970146027
# [13:28:52 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 285.5574657056718,
#  'H2': 0.22502658484971366,
#  'H2O': 8.314423520976016,
#  'N2': 2.139209419461165,
#  'O2': 0.00011378330903398219}
# [13:28:52 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 40
# [13:28:52 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:52 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.7747840889347477
# [13:28:52 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 231.56901177717967,
#  'H2': 1.507873228529043,
#  'H2O': 7.78933704790622,
#  'N2': 2.125842098429624,
#  'O2': 2.2240946409054423e-06}
# [13:28:52 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 41
# [13:28:52 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:52 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.9948337677793544
# [13:28:52 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 107.25689834397308,
#  'H2': 0.1543283658080465,
#  'H2O': 4.0442214555102565,
#  'N2': 2.1325203425960515,
#  'O2': 5.723481390210392e-05}
# [13:28:52 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 42
# [13:28:52 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:52 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.9599265909222882
# [13:28:52 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 66.51693503434406,
#  'H2': 0.13886606487563885,
#  'H2O': 7.417813874657414,
#  'N2': 2.086117012233415,
#  'O2': 0.0002378162564311274}
# [13:28:52 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 43
# [13:28:53 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:53 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.8811704772472607
# [13:28:53 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 541.7722265207613,
#  'H2': 2.8128281464090525,
#  'H2O': 22.172612598610495,
#  'N2': 2.123166597781404,
#  'O2': 5.1788015812723245e-06}
# [13:28:53 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 44
# [13:28:53 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:53 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.8591641279609789
# [13:28:53 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 108.64966177772351,
#  'H2': 0.5740607353530783,
#  'H2O': 1.6097802177368938,
#  'N2': 2.14108004707817,
#  'O2': 6.553894082596979e-07}
# [13:28:53 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 45
# [13:28:53 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:53 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.8239977567778859
# [13:28:53 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 494.4935244668433,
#  'H2': 15.401166399863676,
#  'H2O': 14.464153521683771,
#  'N2': 2.084919233355982,
#  'O2': 7.351242533490626e-08}
# [13:28:53 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 46
# [13:28:54 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:54 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.7829023175006119
# [13:28:54 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 154.7702130959018,
#  'H2': 0.8484432339071312,
#  'H2O': 15.662202528127207,
#  'N2': 2.085425555375528,
#  'O2': 2.8401548683072817e-05}
# [13:28:54 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 47
# [13:28:54 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:54 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 1.0396690121685408
# [13:28:54 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 88.89082747393167,
#  'H2': 0.25476651819529833,
#  'H2O': 0.5857402352115427,
#  'N2': 2.1512761582994644,
#  'O2': 4.405623125930499e-07}
# [13:28:54 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 48
# [13:28:55 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:55 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 1.1807049667307787
# [13:28:55 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 40.35391243999394,
#  'H2': 0.0463326359182869,
#  'H2O': 1.445704088076121,
#  'N2': 2.135123211510449,
#  'O2': 8.114592841214768e-05}
# [13:28:55 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 49
# [13:28:55 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:55 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.7997960896491747
# [13:28:55 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 348.47203299660686,
#  'H2': 3.2192182837123733,
#  'H2O': 22.111606619930708,
#  'N2': 2.101616201258598,
#  'O2': 3.932073974263096e-06}
# [13:28:55 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 50
# [13:28:56 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:56 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.7067814015171917
# [13:28:56 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 201.46426861802243,
#  'H2': 2.865733505068567,
#  'H2O': 6.077084492116751,
#  'N2': 2.1144210122370177,
#  'O2': 3.7480111882627013e-07}
# [13:28:56 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 51
# [13:28:56 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:56 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.8475327613705509
# [13:28:56 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 289.0607704199346,
#  'H2': 1.0337620058896817,
#  'H2O': 6.421613266895093,
#  'N2': 2.1388615836299465,
#  'O2': 3.2160966658121463e-06}
# [13:28:56 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 52
# [13:28:57 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:57 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.777173961199681
# [13:28:57 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 11.253032275128467,
#  'H2': 8.140728496353324,
#  'H2O': 0.3102106312752781,
#  'N2': 1.390255177002808,
#  'O2': 1.210232316942986e-10}
# [13:28:57 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 53
# [13:28:57 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:57 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.6464523847899364
# [13:28:57 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 132.99579421312743,
#  'H2': 23.2903570536435,
#  'H2O': 3.9832187870817113,
#  'N2': 1.865171151026151,
#  'O2': 2.437799380572222e-09}
# [13:28:57 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 54
# [13:28:57 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:57 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 1.2492577463189716
# [13:28:57 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 98.0980132205841,
#  'H2': 0.05870421944730117,
#  'H2O': 0.6578588331372559,
#  'N2': 2.1553975738207827,
#  'O2': 1.0466674470425605e-05}
# [13:28:57 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 55
# [13:28:58 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:58 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.7842877793942288
# [13:28:58 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 13.656216854128727,
#  'H2': 3.836092580589496,
#  'H2O': 0.300386502260957,
#  'N2': 1.767098501707641,
#  'O2': 5.110514209840856e-10}
# [13:28:58 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 56
# [13:28:58 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:58 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.8159081523271006
# [13:28:58 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 440.903850985294,
#  'H2': 4.822763428406979,
#  'H2O': 18.259538114169644,
#  'N2': 2.112662236051389,
#  'O2': 1.1947295059197376e-06}
# [13:28:58 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 57
# [13:28:59 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:59 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.8256081722769266
# [13:28:59 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 60.82544010152204,
#  'H2': 170.19514875885048,
#  'H2O': 11.74877975938969,
#  'N2': 0.7441148775603553,
#  'O2': 3.9716695194564465e-10}
# [13:28:59 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 58
# [13:28:59 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:59 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.9303457493203201
# [13:28:59 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 111.89471741979249,
#  'H2': 259.38093391245496,
#  'H2O': 15.63505834594272,
#  'N2': 0.8105745102946612,
#  'O2': 3.0283414814478165e-10}
# [13:28:59 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 59
# [13:28:59 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:28:59 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.932266548500937
# [13:28:59 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 296.717814913552,
#  'H2': 164.79228171293718,
#  'H2O': 9.642685980369768,
#  'N2': 1.4636626601793512,
#  'O2': 2.853673261657265e-10}
# [13:28:59 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 60
# [13:29:00 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:29:00 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.8110013411202656
# [13:29:00 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 18.09314169870043,
#  'H2': 77.70578154221337,
#  'H2O': 1.1674475550369652,
#  'N2': 0.5639773306595357,
#  'O2': 1.881265219858826e-11}
# [13:29:00 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 61
# [13:29:00 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:29:00 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.681343727181594
# [13:29:00 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 182.97473733330725,
#  'H2': 4.046378385930724,
#  'H2O': 20.703914824955742,
#  'N2': 2.0516229286932752,
#  'O2': 2.1819957102608797e-06}
# [13:29:00 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 62
# [13:29:01 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:29:01 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.9617321236770338
# [13:29:01 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 31.092255354225724,
#  'H2': 0.11489960762665802,
#  'H2O': 4.060490695091623,
#  'N2': 2.0753573233807785,
#  'O2': 0.00010408829151581103}
# [13:29:01 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 63
# [13:29:01 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:29:01 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.9238839230372262
# [13:29:01 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 54.689971130602046,
#  'H2': 280.6961020182626,
#  'H2O': 12.022749686306037,
#  'N2': 0.5338588770173563,
#  'O2': 1.5290327203761222e-10}
# [13:29:01 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 64
# [13:29:01 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:29:01 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.6301489327776446
# [13:29:01 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 49.13512576324491,
#  'H2': 0.9736981977404257,
#  'H2O': 9.72727292467982,
#  'N2': 2.015158056091889,
#  'O2': 8.317932706860626e-06}
# [13:29:01 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 65
# [13:29:01 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:29:01 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.8792466994865207
# [13:29:01 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 9.263307036319748,
#  'H2': 77.42379542570622,
#  'H2O': 0.8894582750780277,
#  'N2': 0.3949048608884941,
#  'O2': 1.0999784517551142e-11}
# [13:29:01 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 66
# [13:29:02 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:29:02 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.7726753892950611
# [13:29:02 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 139.08970926530762,
#  'H2': 0.8472338027337841,
#  'H2O': 5.299085511294453,
#  'N2': 2.1238455320170853,
#  'O2': 3.2604476991197612e-06}
# [13:29:02 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 67
# [13:29:02 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:29:02 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.859966053761925
# [13:29:02 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 38.46646583256908,
#  'H2': 135.77509546464182,
#  'H2O': 1.6602174090657984,
#  'N2': 0.6166826720908037,
#  'O2': 1.246153741210318e-11}
# [13:29:02 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 68
# [13:29:03 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:29:03 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 1.088323864985555
# [13:29:03 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 263.1843375632567,
#  'H2': 0.138509165799376,
#  'H2O': 9.15093064561889,
#  'N2': 2.135831590475761,
#  'O2': 0.0003637939167191565}
# [13:29:03 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 69
# [13:29:03 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:29:03 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.9427043288237795
# [13:29:03 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 314.51472669309845,
#  'H2': 0.5156660159603,
#  'H2O': 19.748028090549862,
#  'N2': 2.115248086806408,
#  'O2': 0.0001222341010368662}
# [13:29:03 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 70
# [13:29:03 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:29:03 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.9963312211856402
# [13:29:03 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 88.27890251763365,
#  'H2': 0.16949071260124737,
#  'H2O': 2.01191766013691,
#  'N2': 2.1418258632950073,
#  'O2': 1.1743850837378131e-05}
# [13:29:03 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 71
# [13:29:04 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:29:04 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.615886118317434
# [13:29:04 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 147.82467984498328,
#  'H2': 14.29359838633698,
#  'H2O': 8.485970230442177,
#  'N2': 1.965735254482465,
#  'O2': 2.9376617545296186e-08}
# [13:29:04 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 72
# [13:29:04 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:29:04 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.8675635060604059
# [13:29:04 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 471.0585334586124,
#  'H2': 40.19105537483627,
#  'H2O': 21.208022360517116,
#  'N2': 1.9874100567673738,
#  'O2': 2.3207238018390862e-08}
# [13:29:04 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 73
# [13:29:04 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:29:04 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.8048081401031572
# [13:29:04 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 17.247455608228634,
#  'H2': 141.58878467142145,
#  'H2O': 7.48936492037115,
#  'N2': 0.43937340926505375,
#  'O2': 2.3319230137061466e-10}
# [13:29:04 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 74
# [13:29:05 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:29:05 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.5873471687486639
# [13:29:05 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 103.60013075379098,
#  'H2': 3.4575476525158844,
#  'H2O': 8.070080525494664,
#  'N2': 2.0540039925663716,
#  'O2': 4.54047532630275e-07}
# [13:29:05 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 75
# [13:29:05 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:29:05 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.6305850813856063
# [13:29:05 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 149.4010831397976,
#  'H2': 5.531739400842116,
#  'H2O': 5.310004955045467,
#  'N2': 2.0718060223873165,
#  'O2': 7.679772589804685e-08}
# [13:29:05 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 76
# [13:29:05 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:29:05 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.9018637174586531
# [13:29:05 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 135.647226826541,
#  'H2': 197.17392452796778,
#  'H2O': 4.745854759848604,
#  'N2': 0.9965937878844846,
#  'O2': 4.828495789785859e-11}
# [13:29:05 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 77
# [13:29:06 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:29:06 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.9670350230063405
# [13:29:06 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 164.40570121168713,
#  'H2': 0.2662532811339834,
#  'H2O': 3.0179655985952456,
#  'N2': 2.1452351155158396,
#  'O2': 1.0708300876590078e-05}
# [13:29:06 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 78
# [13:29:06 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:29:06 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.8446057951912604
# [13:29:06 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 257.764387383224,
#  'H2': 0.907556023383555,
#  'H2O': 15.268686507991859,
#  'N2': 2.1143178060169054,
#  'O2': 2.3590568229411664e-05}
# [13:29:06 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 79
# [13:29:06 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:29:06 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.8528495573427114
# [13:29:06 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 577.790793389833,
#  'H2': 9.886509715094595,
#  'H2O': 18.81494421414687,
#  'N2': 2.1074159033511974,
#  'O2': 3.01857386250962e-07}
# [13:29:06 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 80
# [13:29:07 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:29:07 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 1.2431708016362797
# [13:29:07 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 95.32938438880244,
#  'H2': 0.03561167178074872,
#  'H2O': 2.687294029679356,
#  'N2': 2.1409041212101796,
#  'O2': 0.0004745998348028283}
# [13:29:07 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 81
# [13:29:07 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:29:07 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.5080570370205473
# [13:29:07 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 39.14421474155247,
#  'H2': 13.473459581124683,
#  'H2O': 2.7317551501673774,
#  'N2': 1.6679675374132512,
#  'O2': 3.426156726383711e-09}
# [13:29:07 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 82
# [13:29:07 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:29:07 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.8034135921850708
# [13:29:07 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 5.452248188315053,
#  'H2': 54.27784962243746,
#  'H2O': 1.5965830435348203,
#  'N2': 0.39054181670669635,
#  'O2': 7.211401739679403e-11}
# [13:29:07 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 83
# [13:29:08 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:29:08 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.6569204998474988
# [13:29:08 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 117.08533379477768,
#  'H2': 2.0019754384486363,
#  'H2O': 5.474746876213366,
#  'N2': 2.099212841591348,
#  'O2': 6.232934042349275e-07}
# [13:29:08 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 84
# [13:29:08 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:29:08 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.7169238080753906
# [13:29:08 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 92.06661142105861,
#  'H2': 81.50270750610625,
#  'H2O': 10.629825103445832,
#  'N2': 1.2598055370088577,
#  'O2': 1.4177187977410477e-09}
# [13:29:08 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 85
# [13:29:08 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:29:08 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.7677267113199473
# [13:29:08 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 209.2090129888257,
#  'H2': 1.4460498664402455,
#  'H2O': 6.096244414418828,
#  'N2': 2.1281643677451014,
#  'O2': 1.4812901473125207e-06}
# [13:29:08 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 86
# [13:29:09 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:29:09 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.6562755826207514
# [13:29:09 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 130.50233990077763,
#  'H2': 36.313168923045986,
#  'H2O': 12.801617235918842,
#  'N2': 1.7218753971329288,
#  'O2': 1.0358176522050676e-08}
# [13:29:09 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 87
# [13:29:09 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:29:09 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 1.170747468753706
# [13:29:09 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 339.3673197239101,
#  'H2': 0.09726447655218076,
#  'H2O': 7.551492049966526,
#  'N2': 2.144866144689189,
#  'O2': 0.0005023876600033588}
# [13:29:09 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 88
# [13:29:09 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:29:09 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.7678464097206686
# [13:29:09 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 84.31377932457075,
#  'H2': 115.84207640079242,
#  'H2O': 10.811733427733163,
#  'N2': 1.0504920789866803,
#  'O2': 7.260055219286046e-10}
# [13:29:09 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 89
# [13:29:10 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:29:10 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 1.3115761577817213
# [13:29:10 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 9.037602329583303,
#  'H2': 0.032003303300755355,
#  'H2O': 0.4100827309734646,
#  'N2': 2.1300904778158527,
#  'O2': 1.3684699947476135e-05}
# [13:29:10 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 90
# [13:29:10 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:29:10 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.9682028913449254
# [13:29:10 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 89.79652436225105,
#  'H2': 0.15378864485725116,
#  'H2O': 13.941185044147575,
#  'N2': 2.061612116629521,
#  'O2': 0.0006849088460717381}
# [13:29:10 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 91
# [13:29:10 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:29:10 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.8559043069570573
# [13:29:10 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 516.8302147301434,
#  'H2': 20.930188340481287,
#  'H2O': 24.60230634792744,
#  'N2': 2.058051699132469,
#  'O2': 1.1515619422138026e-07}
# [13:29:10 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 92
# [13:29:10 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:29:10 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.5992927216053923
# [13:29:10 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 63.87298016000302,
#  'H2': 42.7947258645355,
#  'H2O': 7.54283984996075,
#  'N2': 1.3915982837963798,
#  'O2': 2.589233446818255e-09}
# [13:29:10 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 93
# [13:29:11 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:29:11 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.8570844285358908
# [13:29:11 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 333.8579272382539,
#  'H2': 1.2874305260103742,
#  'H2O': 20.928211743685953,
#  'N2': 2.1114333194509856,
#  'O2': 2.2024120208312818e-05}
# [13:29:11 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 94
# [13:29:11 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:29:11 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.7978454858994662
# [13:29:11 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 59.76449382601276,
#  'H2': 0.4362539619669215,
#  'H2O': 2.9937433614932267,
#  'N2': 2.114795782791194,
#  'O2': 3.924933467519429e-06}
# [13:29:11 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 95
# [13:29:11 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:29:11 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.9325010909738246
# [13:29:11 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 372.0714631816415,
#  'H2': 0.6625439448422502,
#  'H2O': 15.826246083545588,
#  'N2': 2.128262595694507,
#  'O2': 4.7556335517258884e-05}
# [13:29:11 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 96
# [13:29:12 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:29:12 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.6772979193430448
# [13:29:12 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 108.60004669577575,
#  'H2': 42.13088994157641,
#  'H2O': 3.527428465195566,
#  'N2': 1.61782324811069,
#  'O2': 5.842478147680084e-10}
# [13:29:12 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 97
# [13:29:12 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:29:12 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.8068793833354192
# [13:29:12 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 246.78047835504748,
#  'H2': 62.73881468365251,
#  'H2O': 21.26709501102014,
#  'N2': 1.7493780074615761,
#  'O2': 9.576915510776555e-09}
# [13:29:12 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 98
# [13:29:12 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:29:12 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 0.9314947582920862
# [13:29:12 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 43.38608342709268,
#  'H2': 268.65972267465764,
#  'H2O': 4.695489272305688,
#  'N2': 0.4625786953594474,
#  'O2': 2.5458834230504073e-11}
# [13:29:12 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 99
# [13:29:13 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:29:13 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionConstant: RMSE (actual vs initial) = 1.0419605847207853
# [13:29:13 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 178.33008175260704,
#  'H2': 420.632224942656,
#  'H2O': 10.874975373075412,
#  'N2': 0.7826260317343459,
#  'O2': 5.5710032776927316e-11}

# %% [markdown]
# The simulation data can be exported to an Excel or a pickle file by setting the appropriate keyword argument in the output method:

# %%
interior_atmosphere.output(file_prefix='tutorial3b_monte_carlo', to_pickle=True)
# Out:
# [13:29:38 - atmodeller.output              - INFO     ] - Output written to tutorial3b_monte_carlo.pkl
# {'atmosphere': [{'total_pressure': 561.4163434720192,
#    'mean_molar_mass': 0.013445087003580615},
#   {'total_pressure': 35.13413922182244,
#    'mean_molar_mass': 0.027293578069171893},
#   {'total_pressure': 185.38701284437565,
#    'mean_molar_mass': 0.013339845208383385},
#   {'total_pressure': 159.69514818475963,
#    'mean_molar_mass': 0.0218547046601018},
#   {'total_pressure': 459.2939587654929,
#    'mean_molar_mass': 0.00819751650312897},
#   {'total_pressure': 158.5487206695544, 'mean_molar_mass': 0.0265453777355581},
#   {'total_pressure': 328.4916827312914,
#    'mean_molar_mass': 0.01545969287133041},
#   {'total_pressure': 17.703563425863965,
#    'mean_molar_mass': 0.027720921057207488},
#   {'total_pressure': 231.90417445716903,
#    'mean_molar_mass': 0.024517649005177757},
#   {'total_pressure': 360.27790098222886,
#    'mean_molar_mass': 0.024520153673356825},
#   {'total_pressure': 186.6358072701631,
#    'mean_molar_mass': 0.009359062230907204},
#   {'total_pressure': 68.81690302696418,
#    'mean_molar_mass': 0.016823725253375627},
#   {'total_pressure': 393.514678194196,
#    'mean_molar_mass': 0.022018066009465743},
#   {'total_pressure': 202.87914536017104,
#    'mean_molar_mass': 0.008781255103574774},
#   {'total_pressure': 145.58562008061043,
#    'mean_molar_mass': 0.027843412793336575},
#   {'total_pressure': 63.449489150288784,
#    'mean_molar_mass': 0.016232943250622665},
#   {'total_pressure': 449.2118038178047,
#    'mean_molar_mass': 0.009343556822654836},
#   {'total_pressure': 67.58696245540388,
#    'mean_molar_mass': 0.025936083122648154},
#   {'total_pressure': 98.0608575706511,
#    'mean_molar_mass': 0.027910724792202135},
#   {'total_pressure': 288.12487247183316,
#    'mean_molar_mass': 0.027460128511523456},
#   {'total_pressure': 319.2592622788962,
#    'mean_molar_mass': 0.003734252244760679},
#   {'total_pressure': 43.50667170596564,
#    'mean_molar_mass': 0.027865211297996496},
#   {'total_pressure': 187.89404999014675,
#    'mean_molar_mass': 0.027585615111271482},
#   {'total_pressure': 65.9060329764992,
#    'mean_molar_mass': 0.027892371169615113},
#   {'total_pressure': 135.04717922961217,
#    'mean_molar_mass': 0.027480237415130008},
#   {'total_pressure': 27.734791532576626,
#    'mean_molar_mass': 0.027392960562857033},
#   {'total_pressure': 383.48306839963584,
#    'mean_molar_mass': 0.027414870036392213},
#   {'total_pressure': 46.54490461284748,
#    'mean_molar_mass': 0.026533945494420667},
#   {'total_pressure': 203.57706736744714,
#    'mean_molar_mass': 0.010071669548199418},
#   {'total_pressure': 235.44095175566895,
#    'mean_molar_mass': 0.02775083566060602},
#   {'total_pressure': 495.7708464626739,
#    'mean_molar_mass': 0.016126969996793045},
#   {'total_pressure': 299.6612656546887,
#    'mean_molar_mass': 0.027746936853927366},
#   {'total_pressure': 158.75591823315898,
#    'mean_molar_mass': 0.027864398415480617},
#   {'total_pressure': 356.2096442953056,
#    'mean_molar_mass': 0.02734129368679527},
#   {'total_pressure': 318.50222961776984,
#    'mean_molar_mass': 0.0046207096120827},
#   {'total_pressure': 224.7922410152686,
#    'mean_molar_mass': 0.026804338783577967},
#   {'total_pressure': 132.56968707578528,
#    'mean_molar_mass': 0.027546135763729402},
#   {'total_pressure': 491.9599835679091,
#    'mean_molar_mass': 0.01970941379688213},
#   {'total_pressure': 112.98870510666953,
#    'mean_molar_mass': 0.025247557583071966},
#   {'total_pressure': 296.2362390142677,
#    'mean_molar_mass': 0.02770989998891314},
#   {'total_pressure': 242.99206637613918,
#    'mean_molar_mass': 0.027528473184601807},
#   {'total_pressure': 113.58802574270133,
#    'mean_molar_mass': 0.02761903080844912},
#   {'total_pressure': 76.15996980236696,
#    'mean_molar_mass': 0.026989372983354434},
#   {'total_pressure': 568.8808390423637,
#    'mean_molar_mass': 0.027492070660887036},
#   {'total_pressure': 112.97458343328107,
#    'mean_molar_mass': 0.027735704282434714},
#   {'total_pressure': 526.4437636952592,
#    'mean_molar_mass': 0.026975082247229245},
#   {'total_pressure': 173.36631281486035,
#    'mean_molar_mass': 0.02698001850055519},
#   {'total_pressure': 91.88261082620029,
#    'mean_molar_mass': 0.027874430078836422},
#   {'total_pressure': 43.98115352142721,
#    'mean_molar_mass': 0.02765438572039076},
#   {'total_pressure': 375.9044780335825,
#    'mean_molar_mass': 0.02719962870187301},
#   {'total_pressure': 212.5215080022459,
#    'mean_molar_mass': 0.027373854905784843},
#   {'total_pressure': 298.65501049244597,
#    'mean_molar_mass': 0.027705284865933096},
#   {'total_pressure': 21.0942265798809, 'mean_molar_mass': 0.01783161513924381},
#   {'total_pressure': 162.13454120731657,
#    'mean_molar_mass': 0.024030602543230993},
#   {'total_pressure': 100.9699843136639, 'mean_molar_mass': 0.0279299814930306},
#   {'total_pressure': 19.559794439197873,
#    'mean_molar_mass': 0.022758916124541194},
#   {'total_pressure': 466.0988159586515,
#    'mean_molar_mass': 0.02734964390700454},
#   {'total_pressure': 243.51348349771973,
#    'mean_molar_mass': 0.009360161632601028},
#   {'total_pressure': 387.72128418878765,
#    'mean_molar_mass': 0.010217250879047846},
#   {'total_pressure': 472.6164452673237,
#    'mean_molar_mass': 0.01874253178174637},
#   {'total_pressure': 97.53034812662914,
#    'mean_molar_mass': 0.0071800014143744385},
#   {'total_pressure': 209.7766556548827, 'mean_molar_mass': 0.0265223311502608},
#   {'total_pressure': 37.3431070686163,
#    'mean_molar_mass': 0.026843568915867443},
#   {'total_pressure': 347.9426817123409,
#    'mean_molar_mass': 0.0066944150717040025},
#   {'total_pressure': 61.85126325968975,
#    'mean_molar_mass': 0.026029155969560965},
#   {'total_pressure': 87.97146559800348,
#    'mean_molar_mass': 0.005031521097530698},
#   {'total_pressure': 147.35987737180062,
#    'mean_molar_mass': 0.027501323413159893},
#   {'total_pressure': 176.51846137837995,
#    'mean_molar_mass': 0.00792179198060973},
#   {'total_pressure': 274.6099727590675,
#    'mean_molar_mass': 0.02766400214473295},
#   {'total_pressure': 336.893791120516,
#    'mean_molar_mass': 0.027384500613654515},
#   {'total_pressure': 92.60214849751766,
#    'mean_molar_mass': 0.027745490383002586},
#   {'total_pressure': 172.56998374562153,
#    'mean_molar_mass': 0.025365645633243488},
#   {'total_pressure': 534.4450212739405,
#    'mean_molar_mass': 0.025658730907708652},
#   {'total_pressure': 166.76497860951946,
#    'mean_molar_mass': 0.005491329334966817},
#   {'total_pressure': 117.18176337841543,
#    'mean_molar_mass': 0.02655489285938609},
#   {'total_pressure': 162.31463359487023,
#    'mean_molar_mass': 0.026797318568320887},
#   {'total_pressure': 338.56359990229015,
#    'mean_molar_mass': 0.012731415251923704},
#   {'total_pressure': 169.8351659152331, 'mean_molar_mass': 0.0277918265092569},
#   {'total_pressure': 276.05497131118454,
#    'mean_molar_mass': 0.027371893083250026},
#   {'total_pressure': 608.5996635242831,
#    'mean_molar_mass': 0.02727889524327134},
#   {'total_pressure': 100.19366881130753,
#    'mean_molar_mass': 0.027732922424816613},
#   {'total_pressure': 57.01739701368394,
#    'mean_molar_mass': 0.021388819979815277},
#   {'total_pressure': 61.71722267106614,
#    'mean_molar_mass': 0.004890682009692569},
#   {'total_pressure': 126.66126957432444,
#    'mean_molar_mass': 0.02716732741243079},
#   {'total_pressure': 185.45894956903726,
#    'mean_molar_mass': 0.016013731219278866},
#   {'total_pressure': 218.87947311872003,
#    'mean_molar_mass': 0.027560065554272508},
#   {'total_pressure': 181.33900146723354,
#    'mean_molar_mass': 0.022099233469425925},
#   {'total_pressure': 349.16144478277795,
#    'mean_molar_mass': 0.027786765780981285},
#   {'total_pressure': 212.018081232809, 'mean_molar_mass': 0.0132977785028728},
#   {'total_pressure': 11.609792526373322,
#    'mean_molar_mass': 0.027586052999450984},
#   {'total_pressure': 105.95379507673147,
#    'mean_molar_mass': 0.026657401264337122},
#   {'total_pressure': 564.4207612328407,
#    'mean_molar_mass': 0.02661056029072981},
#   {'total_pressure': 115.60214416088488,
#    'mean_molar_mass': 0.017735228016736024},
#   {'total_pressure': 358.18502485152146,
#    'mean_molar_mass': 0.027332748341306345},
#   {'total_pressure': 65.30929085719757,
#    'mean_molar_mass': 0.02737845496841411},
#   {'total_pressure': 390.6885633620593,
#    'mean_molar_mass': 0.02756120354041542},
#   {'total_pressure': 155.87618835124266,
#    'mean_molar_mass': 0.02075815663402181},
#   {'total_pressure': 332.53576606675864,
#    'mean_molar_mass': 0.022466665689648693},
#   {'total_pressure': 317.20387406944093,
#    'mean_molar_mass': 0.005846037612014537},
#   {'total_pressure': 610.6199081001286,
#    'mean_molar_mass': 0.009925710120933682}],
#  'constraints': [{'H_mass': 1.481732100148139e+21,
#    'C_mass': 1.0939813523253744e+21,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 2.3211509283051684e-10},
#   {'H_mass': 4.288491227570151e+20,
#    'C_mass': 7.049653605964694e+19,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 7.364634092712888e-06},
#   {'H_mass': 7.10016132110412e+20,
#    'C_mass': 3.6063263377160025e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 1.398754279725466e-10},
#   {'H_mass': 7.117251427868903e+20,
#    'C_mass': 3.339863405334336e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 1.728448352532293e-09},
#   {'H_mass': 1.2357523734471964e+21,
#    'C_mass': 7.95341284300685e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 3.016635051335983e-11},
#   {'H_mass': 9.85897162286195e+20,
#    'C_mass': 3.318285207627686e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 3.628476816015619e-07},
#   {'H_mass': 1.377638682435111e+21,
#    'C_mass': 6.379730447930332e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 1.0656101108946495e-09},
#   {'H_mass': 1.6722547551916333e+20,
#    'C_mass': 3.416514106210775e+19,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 1.1318042610535535e-06},
#   {'H_mass': 1.5088184058743604e+21,
#    'C_mass': 4.6854115979176064e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 9.855872374796977e-08},
#   {'H_mass': 1.144252095080433e+21,
#    'C_mass': 7.675670756662466e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 8.166574580467872e-09},
#   {'H_mass': 1.4694395862295105e+21,
#    'C_mass': 2.7097741518443613e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 1.7542769316296625e-09},
#   {'H_mass': 4.3950286070822266e+20,
#    'C_mass': 1.3613227665544947e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 3.6197784832122884e-10},
#   {'H_mass': 8.934514734442308e+20,
#    'C_mass': 8.395938262567765e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 6.500022853244972e-10},
#   {'H_mass': 1.1647845410609855e+21,
#    'C_mass': 3.250800059236295e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 4.1496172556526304e-10},
#   {'H_mass': 3.381499721202413e+20,
#    'C_mass': 3.175970728167256e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 5.875479191785205e-07},
#   {'H_mass': 2.521255031622493e+20,
#    'C_mass': 1.2714857803086465e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 3.5256492480543934e-11},
#   {'H_mass': 9.385082101818978e+20,
#    'C_mass': 8.26068864849741e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 1.0216512308892832e-11},
#   {'H_mass': 3.5446005816426935e+20,
#    'C_mass': 1.4279479165812995e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 6.232657346694428e-09},
#   {'H_mass': 2.9532497925550853e+20,
#    'C_mass': 2.122402973531398e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 0.0003266504635925768},
#   {'H_mass': 1.1899950802113798e+21,
#    'C_mass': 6.147878791361842e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 0.00022817014927943298},
#   {'H_mass': 1.447675906233695e+21,
#    'C_mass': 3.071158154033385e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 1.4712931690263495e-11},
#   {'H_mass': 2.2247212820533982e+20,
#    'C_mass': 9.131229888292554e+19,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 1.615298497891553e-05},
#   {'H_mass': 5.938563036588237e+20,
#    'C_mass': 4.079179783701016e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 4.531798491508918e-07},
#   {'H_mass': 2.523372779633903e+20,
#    'C_mass': 1.4098351809616224e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 3.065772748964285e-05},
#   {'H_mass': 4.409091794191818e+20,
#    'C_mass': 2.9260980416690006e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 9.445123635176268e-08},
#   {'H_mass': 3.2812788601549324e+20,
#    'C_mass': 5.522434449759168e+19,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 2.428148125044838e-06},
#   {'H_mass': 8.604882620522276e+20,
#    'C_mass': 8.368180590647489e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 1.5644150367046315e-07},
#   {'H_mass': 5.4893783819189014e+20,
#    'C_mass': 9.372707057343447e+19,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 4.399147864500439e-07},
#   {'H_mass': 7.773436242358695e+20,
#    'C_mass': 3.6963325542606e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 7.831834369936435e-11},
#   {'H_mass': 5.456650419516766e+20,
#    'C_mass': 5.147777510526536e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 6.720067874421158e-07},
#   {'H_mass': 1.0545067139357525e+21,
#    'C_mass': 1.0152713232000458e+21,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 1.295137791477116e-10},
#   {'H_mass': 8.480257534356904e+20,
#    'C_mass': 6.514637932609811e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 0.0008469362049064126},
#   {'H_mass': 4.022243104250213e+20,
#    'C_mass': 3.4623731145931614e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 5.067981031188879e-06},
#   {'H_mass': 7.83157221963373e+20,
#    'C_mass': 7.778833696788576e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 7.999328249217029e-08},
#   {'H_mass': 1.2158841960800626e+21,
#    'C_mass': 3.9775471083295054e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 1.1833327340335428e-11},
#   {'H_mass': 8.568878760649926e+20,
#    'C_mass': 4.8292339534378684e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 9.190990088451818e-08},
#   {'H_mass': 4.572891293468273e+20,
#    'C_mass': 2.8694153632535747e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 1.8421577670752868e-07},
#   {'H_mass': 1.3899281647005225e+21,
#    'C_mass': 1.0195567481112434e+21,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 1.2282924543835554e-09},
#   {'H_mass': 1.3138317374643595e+21,
#    'C_mass': 2.1681426407427437e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 1.1361449840185334e-06},
#   {'H_mass': 8.817373359362778e+20,
#    'C_mass': 6.428995001109196e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 0.00011378330903397882},
#   {'H_mass': 8.538538570064859e+20,
#    'C_mass': 5.247867303185971e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 2.2240946409041366e-06},
#   {'H_mass': 6.142924076635695e+20,
#    'C_mass': 2.4227094135696038e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 5.723481390211212e-05},
#   {'H_mass': 8.327229552288416e+20,
#    'C_mass': 1.5375312890309217e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 0.00023781625642953994},
#   {'H_mass': 1.444144190271565e+21,
#    'C_mass': 1.2294017119241615e+21,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 5.178801581249066e-06},
#   {'H_mass': 3.8738201790262575e+20,
#    'C_mass': 2.4438452836243263e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 6.553894082599083e-07},
#   {'H_mass': 1.1703097587862247e+21,
#    'C_mass': 1.1436216242381856e+21,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 7.351242533491529e-08},
#   {'H_mass': 1.2121578036412243e+21,
#    'C_mass': 3.578736022655824e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 2.840154868307514e-05},
#   {'H_mass': 2.334915004038725e+20,
#    'C_mass': 1.9894612287641784e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 4.4056231259289044e-07},
#   {'H_mass': 3.668933378367743e+20,
#    'C_mass': 9.103453091867248e+19,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 8.11459284121344e-05},
#   {'H_mass': 1.4424044785395727e+21,
#    'C_mass': 7.992625805537537e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 3.932073974263522e-06},
#   {'H_mass': 7.544874656908377e+20,
#    'C_mass': 4.5914155209907405e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 3.7480111882607007e-07},
#   {'H_mass': 7.748810504743133e+20,
#    'C_mass': 6.508951916905162e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 3.2160966658121463e-06},
#   {'H_mass': 1.746535924067935e+20,
#    'C_mass': 3.936981823546099e+19,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 1.2102323169430056e-10},
#   {'H_mass': 6.199460074464228e+20,
#    'C_mass': 3.452691488195402e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 2.4377993805796507e-09},
#   {'H_mass': 2.473825772057312e+20,
#    'C_mass': 2.191159999923821e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 1.0466674470425776e-05},
#   {'H_mass': 1.688856432697044e+20,
#    'C_mass': 3.743375181649587e+19,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 5.110514209840836e-10},
#   {'H_mass': 1.310731532593741e+21,
#    'C_mass': 1.0057192048312734e+21,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 1.1947295059197376e-06},
#   {'H_mass': 1.24783745017989e+21,
#    'C_mass': 4.05402515446668e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 3.9716695194579897e-10},
#   {'H_mass': 1.486545547551729e+21,
#    'C_mass': 6.832191864378816e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 3.0283414814478165e-10},
#   {'H_mass': 1.0435351952615464e+21,
#    'C_mass': 9.876427807533523e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 2.853673261655152e-10},
#   {'H_mass': 4.442153065820249e+20,
#    'C_mass': 1.572077608808998e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 1.881265219858611e-11},
#   {'H_mass': 1.3960709128404324e+21,
#    'C_mass': 4.303917783840106e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 2.1819957102605943e-06},
#   {'H_mass': 6.155605164204058e+20,
#    'C_mass': 7.225975710965966e+19,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 0.00010408829151581081},
#   {'H_mass': 1.5142551292313846e+21,
#    'C_mass': 5.09658868111004e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 1.5290327203695493e-10},
#   {'H_mass': 9.545296813145058e+20,
#    'C_mass': 1.1776507517355503e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 8.317932706860626e-06},
#   {'H_mass': 4.5031147599517594e+20,
#    'C_mass': 1.1485536558766481e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 1.0999784517551142e-11},
#   {'H_mass': 7.036845747436976e+20,
#    'C_mass': 3.155193025650697e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 3.2604476991259293e-06},
#   {'H_mass': 5.742247263370761e+20,
#    'C_mass': 3.029307639150242e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 1.2461537412103792e-11},
#   {'H_mass': 9.251607333986075e+20,
#    'C_mass': 5.935120758571768e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 0.00036379391669612906},
#   {'H_mass': 1.361667315645552e+21,
#    'C_mass': 7.16507412748813e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 0.00012223410103428338},
#   {'H_mass': 4.3297470566558656e+20,
#    'C_mass': 1.9849476057538275e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 1.1743850837378155e-05},
#   {'H_mass': 8.969304263404695e+20,
#    'C_mass': 3.635679183445664e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 2.9376617545290658e-08},
#   {'H_mass': 1.428130999413901e+21,
#    'C_mass': 1.1453131071964266e+21,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 2.320723801839077e-08},
#   {'H_mass': 1.1180440829135478e+21,
#    'C_mass': 1.9594404648362348e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 2.3319230137064423e-10},
#   {'H_mass': 8.700509228781778e+20,
#    'C_mass': 2.4338862512435963e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 4.5404753263030936e-07},
#   {'H_mass': 7.063029798175526e+20,
#    'C_mass': 3.4781390012963946e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 7.679772589805062e-08},
#   {'H_mass': 8.297914113249186e+20,
#    'C_mass': 6.646894158547725e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 4.8284957897975304e-11},
#   {'H_mass': 5.305204663771753e+20,
#    'C_mass': 3.690492365029082e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 1.070830087659023e-05},
#   {'H_mass': 1.196694427033126e+21,
#    'C_mass': 5.874928801376176e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 2.359056822937302e-05},
#   {'H_mass': 1.3325630689763567e+21,
#    'C_mass': 1.3213819402168484e+21,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 3.0185738625018174e-07},
#   {'H_mass': 5.004739953092408e+20,
#    'C_mass': 2.1444487871272754e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 0.00047459983480282634},
#   {'H_mass': 5.1149383093693075e+20,
#    'C_mass': 1.1417349286087316e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 3.426156726383697e-09},
#   {'H_mass': 5.045952347245312e+20,
#    'C_mass': 6.9548972496854475e+19,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 7.211401739679285e-11},
#   {'H_mass': 7.157558988490637e+20,
#    'C_mass': 2.6886861437585618e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 6.23293404234953e-07},
#   {'H_mass': 1.0535730488008839e+21,
#    'C_mass': 3.586692556925614e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 1.417718797738502e-09},
#   {'H_mass': 7.55115312735205e+20,
#    'C_mass': 4.735705333093267e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 1.4812901473126418e-06},
#   {'H_mass': 1.1133633926043413e+21,
#    'C_mass': 3.684050849917011e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 1.0358176522037818e-08},
#   {'H_mass': 8.401170679499639e+20,
#    'C_mass': 7.61932578616521e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 0.0005023876600553142},
#   {'H_mass': 1.1015227439062463e+21,
#    'C_mass': 3.955523685779687e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 7.260055219286879e-10},
#   {'H_mass': 1.952720086081948e+20,
#    'C_mass': 2.043846091569344e+19,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 1.3684699947475885e-05},
#   {'H_mass': 1.1431132175820364e+21,
#    'C_mass': 2.1014847627959514e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 0.0006849088460717387},
#   {'H_mass': 1.529105327325701e+21,
#    'C_mass': 1.211653396040723e+21,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 1.1515619422137271e-07},
#   {'H_mass': 8.664741144984697e+20,
#    'C_mass': 2.2468026670878405e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 2.589233446818255e-09},
#   {'H_mass': 1.4022992516525166e+21,
#    'C_mass': 7.620139420938337e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 2.2024120208296108e-05},
#   {'H_mass': 5.284666048417577e+20,
#    'C_mass': 1.3618172680977821e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 3.924933467519453e-06},
#   {'H_mass': 1.218312355611721e+21,
#    'C_mass': 8.421951016841116e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 4.75563355172584e-05},
#   {'H_mass': 5.952469087995585e+20,
#    'C_mass': 3.2638166585271524e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 5.842478147680682e-10},
#   {'H_mass': 1.444179739091745e+21,
#    'C_mass': 6.852620894763272e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 9.576915510798295e-09},
#   {'H_mass': 1.1497983636178082e+21,
#    'C_mass': 4.6299187454149604e+20,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 2.5458834230501365e-11},
#   {'H_mass': 1.45992423932412e+21,
#    'C_mass': 1.1208501352363486e+21,
#    'N_mass': 1.178313142326631e+19,
#    'O2_fugacity': 5.5710032776895644e-11}],
#  'planet': [{'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None},
#   {'mantle_mass': 4.208261222595111e+24,
#    'mantle_melt_fraction': 1.0,
#    'core_mass_fraction': 0.295334691460966,
#    'surface_radius': 6371000.0,
#    'surface_temperature': 2000.0,
#    'melt_composition': None}],
#  'H2O': [{'mass_in_atmosphere': 1.132397275194056e+20,
#    'mass_in_solid': 0.0,
#    'mass_in_melt': 1.0982727642825374e+22,
#    'moles_in_atmosphere': 6.285757619037965e+21,
#    'moles_in_melt': 6.096337872843976e+23,
#    'moles_in_solid': 0.0,
#    'ppmw_in_solid': 0.0,
#    'ppmw_in_melt': 2609.801783182236,
#    'fugacity': 16.270709295550684,
#    'fugacity_coefficient': 1.0000000000000013,
#    'pressure': 16.27070929555066,
#    'volume_mixing_ratio': 0.028981538362289564,
#    'mass_in_total': 1.109596737034478e+22,
#    'moles_in_total': 6.159195449034355e+23},
#   {'mass_in_atmosphere': 6.766194330681605e+18,
#    'mass_in_solid': 0.0,
#    'mass_in_melt': 3.825000248752511e+21,
#    'moles_in_atmosphere': 3.7558071268482174e+20,
#    'moles_in_melt': 2.1231969542047876e+23,
#    'moles_in_solid': 0.0,
#    'ppmw_in_solid': 0.0,
#    'ppmw_in_melt': 908.9265248590596,
#    'fugacity': 1.973553907327283,
#    'fugacity_coefficient': 1.000000000000001,
#    'pressure': 1.9735539073272808,
#    'volume_mixing_ratio': 0.05617197264652129,
#    'mass_in_total': 3.8317664430831923e+21,
#    'moles_in_total': 2.1269527613316357e+23},
#   {'mass_in_atmosphere': 2.959979192587907e+19,
#    'mass_in_solid': 0.0,
#    'mass_in_melt': 5.593050256174028e+21,
#    'moles_in_atmosphere': 1.6430374895431346e+21,
#    'moles_in_melt': 3.1046134630961075e+23,
#    'moles_in_solid': 0.0,
#    'ppmw_in_solid': 0.0,
#    'ppmw_in_melt': 1329.064418849208,
#    'fugacity': 4.219718709944086,
#    'fugacity_coefficient': 1.0000000000000009,
#    'pressure': 4.2197187099440825,
#    'volume_mixing_ratio': 0.02276167378286824,
#    'mass_in_total': 5.622650048099908e+21,
#    'moles_in_total': 3.121043837991539e+23},
#   {'mass_in_atmosphere': 2.2093710990722163e+19,
#    'mass_in_solid': 0.0,
#    'mass_in_melt': 6.18494444184266e+21,
#    'moles_in_atmosphere': 1.2263868452787991e+21,
#    'moles_in_melt': 3.433164535121011e+23,
#    'moles_in_solid': 0.0,
#    'ppmw_in_solid': 0.0,
#    'ppmw_in_melt': 1469.714952254933,
#    'fugacity': 5.1600946011235305,
#    'fugacity_coefficient': 1.000000000000001,
#    'pressure': 5.160094601123525,
#    'volume_mixing_ratio': 0.03231215637906258,
#    'mass_in_total': 6.207038152833382e+21,
#    'moles_in_total': 3.445428403573799e+23},
#   {'mass_in_atmosphere': 7.547170298701418e+19,
#    'mass_in_solid': 0.0,
#    'mass_in_melt': 7.001034571490915e+21,
#    'moles_in_atmosphere': 4.189314496461487e+21,
#    'moles_in_melt': 3.8861632187657705e+23,
#    'moles_in_solid': 0.0,
#    'ppmw_in_solid': 0.0,
#    'ppmw_in_melt': 1663.6406822610654,
#    'fugacity': 6.611659853644003,
#    'fugacity_coefficient': 1.0000000000000009,
#    'pressure': 6.611659853643998,
#    'volume_mixing_ratio': 0.014395268493004041,
#    'mass_in_total': 7.076506274477929e+21,
#    'moles_in_total': 3.928056363730385e+23},
#   {'mass_in_atmosphere': 3.6461528924651913e+19,
#    'mass_in_solid': 0.0,
#    'mass_in_melt': 8.756708447570872e+21,
#    'moles_in_atmosphere': 2.0239216241546366e+21,
# ...
#    'CO': 17.247455608228634,
#    'N2': 0.43937340926505375},
#   {'H2O': 8.070080525494664,
#    'H2': 3.4575476525158844,
#    'O2': 4.54047532630275e-07,
#    'CO': 103.60013075379098,
#    'N2': 2.0540039925663716},
#   {'H2O': 5.310004955045467,
#    'H2': 5.531739400842116,
#    'O2': 7.679772589804685e-08,
#    'CO': 149.4010831397976,
#    'N2': 2.0718060223873165},
#   {'H2O': 4.745854759848604,
#    'H2': 197.17392452796778,
#    'O2': 4.828495789785859e-11,
#    'CO': 135.647226826541,
#    'N2': 0.9965937878844846},
#   {'H2O': 3.0179655985952456,
#    'H2': 0.2662532811339834,
#    'O2': 1.0708300876590078e-05,
#    'CO': 164.40570121168713,
#    'N2': 2.1452351155158396},
#   {'H2O': 15.268686507991859,
#    'H2': 0.907556023383555,
#    'O2': 2.3590568229411664e-05,
#    'CO': 257.764387383224,
#    'N2': 2.1143178060169054},
#   {'H2O': 18.81494421414687,
#    'H2': 9.886509715094595,
#    'O2': 3.01857386250962e-07,
#    'CO': 577.790793389833,
#    'N2': 2.1074159033511974},
#   {'H2O': 2.687294029679356,
#    'H2': 0.03561167178074872,
#    'O2': 0.0004745998348028283,
#    'CO': 95.32938438880244,
#    'N2': 2.1409041212101796},
#   {'H2O': 2.7317551501673774,
#    'H2': 13.473459581124683,
#    'O2': 3.426156726383711e-09,
#    'CO': 39.14421474155247,
#    'N2': 1.6679675374132512},
#   {'H2O': 1.5965830435348203,
#    'H2': 54.27784962243746,
#    'O2': 7.211401739679403e-11,
#    'CO': 5.452248188315053,
#    'N2': 0.39054181670669635},
#   {'H2O': 5.474746876213366,
#    'H2': 2.0019754384486363,
#    'O2': 6.232934042349275e-07,
#    'CO': 117.08533379477768,
#    'N2': 2.099212841591348},
#   {'H2O': 10.629825103445832,
#    'H2': 81.50270750610625,
#    'O2': 1.4177187977410477e-09,
#    'CO': 92.06661142105861,
#    'N2': 1.2598055370088577},
#   {'H2O': 6.096244414418828,
#    'H2': 1.4460498664402455,
#    'O2': 1.4812901473125207e-06,
#    'CO': 209.2090129888257,
#    'N2': 2.1281643677451014},
#   {'H2O': 12.801617235918842,
#    'H2': 36.313168923045986,
#    'O2': 1.0358176522050676e-08,
#    'CO': 130.50233990077763,
#    'N2': 1.7218753971329288},
#   {'H2O': 7.551492049966526,
#    'H2': 0.09726447655218076,
#    'O2': 0.0005023876600033588,
#    'CO': 339.3673197239101,
#    'N2': 2.144866144689189},
#   {'H2O': 10.811733427733163,
#    'H2': 115.84207640079242,
#    'O2': 7.260055219286046e-10,
#    'CO': 84.31377932457075,
#    'N2': 1.0504920789866803},
#   {'H2O': 0.4100827309734646,
#    'H2': 0.032003303300755355,
#    'O2': 1.3684699947476135e-05,
#    'CO': 9.037602329583303,
#    'N2': 2.1300904778158527},
#   {'H2O': 13.941185044147575,
#    'H2': 0.15378864485725116,
#    'O2': 0.0006849088460717381,
#    'CO': 89.79652436225105,
#    'N2': 2.061612116629521},
#   {'H2O': 24.60230634792744,
#    'H2': 20.930188340481287,
#    'O2': 1.1515619422138026e-07,
#    'CO': 516.8302147301434,
#    'N2': 2.058051699132469},
#   {'H2O': 7.54283984996075,
#    'H2': 42.7947258645355,
#    'O2': 2.589233446818255e-09,
#    'CO': 63.87298016000302,
#    'N2': 1.3915982837963798},
#   {'H2O': 20.928211743685953,
#    'H2': 1.2874305260103742,
#    'O2': 2.2024120208312818e-05,
#    'CO': 333.8579272382539,
#    'N2': 2.1114333194509856},
#   {'H2O': 2.9937433614932267,
#    'H2': 0.4362539619669215,
#    'O2': 3.924933467519429e-06,
#    'CO': 59.76449382601276,
#    'N2': 2.114795782791194},
#   {'H2O': 15.826246083545588,
#    'H2': 0.6625439448422502,
#    'O2': 4.7556335517258884e-05,
#    'CO': 372.0714631816415,
#    'N2': 2.128262595694507},
#   {'H2O': 3.527428465195566,
#    'H2': 42.13088994157641,
#    'O2': 5.842478147680084e-10,
#    'CO': 108.60004669577575,
#    'N2': 1.61782324811069},
#   {'H2O': 21.26709501102014,
#    'H2': 62.73881468365251,
#    'O2': 9.576915510776555e-09,
#    'CO': 246.78047835504748,
#    'N2': 1.7493780074615761},
#   {'H2O': 4.695489272305688,
#    'H2': 268.65972267465764,
#    'O2': 2.5458834230504073e-11,
#    'CO': 43.38608342709268,
#    'N2': 0.4625786953594474},
#   {'H2O': 10.874975373075412,
#    'H2': 420.632224942656,
#    'O2': 5.5710032776927316e-11,
#    'CO': 178.33008175260704,
#    'N2': 0.7826260317343459}],
#  'extra': [{'fO2_shift': -2.589229121488449,
#    'C/H ratio': 0.7383125142635443,
#    'Number of ocean moles': 9.55955245219208},
#   {'fO2_shift': 1.9266914326661126,
#    'C/H ratio': 0.16438540344080432,
#    'Number of ocean moles': 2.766765788945505},
#   {'fO2_shift': -2.7988502670847035,
#    'C/H ratio': 0.5079217463688833,
#    'Number of ocean moles': 4.580744694761919},
#   {'fO2_shift': -1.7062287621488315,
#    'C/H ratio': 0.4692630911220149,
#    'Number of ocean moles': 4.591770559155029},
#   {'fO2_shift': -3.4726013634735216,
#    'C/H ratio': 0.6436089473832355,
#    'Number of ocean moles': 7.972588047939488},
#   {'fO2_shift': 0.6158707101361616,
#    'C/H ratio': 0.336575185989269,
#    'Number of ocean moles': 6.360620542944269},
#   {'fO2_shift': -1.9209287412534044,
#    'C/H ratio': 0.4630917038895521,
#    'Number of ocean moles': 8.887982681613346},
#   {'fO2_shift': 1.1137909240867936,
#    'C/H ratio': 0.20430583890426773,
#    'Number of ocean moles': 1.078872965233311},
#   {'fO2_shift': 0.04782415374593718,
#    'C/H ratio': 0.3105351564956825,
#    'Number of ocean moles': 9.734302638342488},
#   {'fO2_shift': -1.037361262271391,
#    'C/H ratio': 0.6708024210454183,
#    'Number of ocean moles': 7.382264257053267},
#   {'fO2_shift': -1.7005278847337841,
#    'C/H ratio': 0.1844086805091097,
#    'Number of ocean moles': 9.480245989463304},
#   {'fO2_shift': -2.382704023238227,
#    'C/H ratio': 0.3097415030156653,
#    'Number of ocean moles': 2.8354995139868238},
#   {'fO2_shift': -2.137400322648613,
#    'C/H ratio': 0.9397195608399026,
#    'Number of ocean moles': 5.764197335688766},
#   {'fO2_shift': -2.32706468811746,
#    'C/H ratio': 0.2790902475641708,
#    'Number of ocean moles': 7.514731519052429},
#   {'fO2_shift': 0.8255461354175804,
#    'C/H ratio': 0.9392195741592213,
#    'Number of ocean moles': 2.1816105589313715},
#   {'fO2_shift': -3.3939993095295087,
#    'C/H ratio': 0.5043066902638613,
#    'Number of ocean moles': 1.6266145356329105},
#   {'fO2_shift': -3.9425442145941387,
#    'C/H ratio': 0.8801935410768923,
#    'Number of ocean moles': 6.054885671404295},
#   {'fO2_shift': -1.1466789427293769,
#    'C/H ratio': 0.4028515720435666,
#    'Number of ocean moles': 2.2868368161084036},
#   {'fO2_shift': 3.5718930527400214,
#    'C/H ratio': 0.7186669339254038,
#    'Number of ocean moles': 1.9053205564982492},
#   {'fO2_shift': 3.4108418399757934,
#    'C/H ratio': 0.5166306057559322,
#    'Number of ocean moles': 7.677379997365169},
#   {'fO2_shift': -3.7805739636622953,
#    'C/H ratio': 0.21214404003057402,
#    'Number of ocean moles': 9.339835290085242},
#   {'fO2_shift': 2.2675628031717316,
#    'C/H ratio': 0.41044376938150695,
#    'Number of ocean moles': 1.4353026289415765},
#   {'fO2_shift': 0.7116099515759382,
#    'C/H ratio': 0.6868967725977941,
#    'Number of ocean moles': 3.8313271902011596},
#   {'fO2_shift': 2.5452339910693578,
#    'C/H ratio': 0.558710624264626,
#    'Number of ocean moles': 1.6279808233170048},
#   {'fO2_shift': 0.03200029714500907,
#    'C/H ratio': 0.6636509690099005,
#    'Number of ocean moles': 2.844572528926953},
#   {'fO2_shift': 1.445018917272713,
#    'C/H ratio': 0.16830128389326882,
#    'Number of ocean moles': 2.11695200304995},
#   {'fO2_shift': 0.24431264466465485,
#    'C/H ratio': 0.9724921256554665,
#    'Number of ocean moles': 5.551531666730764},
#   {'fO2_shift': 0.7025950223178761,
#    'C/H ratio': 0.1707425942473848,
#    'Number of ocean moles': 3.541530926314995},
#   {'fO2_shift': -3.05122842762227,
#    'C/H ratio': 0.4755081844138238,
#    'Number of ocean moles': 5.015115180751603},
#   {'fO2_shift': 0.8814054808217353,
#    'C/H ratio': 0.9433951444121312,
#    'Number of ocean moles': 3.5204161328104675},
#   {'fO2_shift': -2.8408112747871437,
#    'C/H ratio': 0.9627926591484015,
#    'Number of ocean moles': 6.803262372496152},
#   {'fO2_shift': 3.980116461150774,
#    'C/H ratio': 0.7682122749475964,
#    'Number of ocean moles': 5.471128465103578},
#   {'fO2_shift': 1.7609756403863974,
#    'C/H ratio': 0.8608065263222281,
#    'Number of ocean moles': 2.5949929765781286},
#   {'fO2_shift': -0.046235799531995525,
#    'C/H ratio': 0.993265908636718,
#    'Number of ocean moles': 5.052622225652943},
#   {'fO2_shift': -3.875145485495179,
#    'C/H ratio': 0.3271320674413631,
#    'Number of ocean moles': 7.8444063856460255},
#   {'fO2_shift': 0.017686958566237365,
#    'C/H ratio': 0.5635782799979288,
#    'Number of ocean moles': 5.528303393084219},
#   {'fO2_shift': 0.3221876025753643,
#    'C/H ratio': 0.6274838344292435,
#    'Number of ocean moles': 2.950249520389817},
#   {'fO2_shift': -1.8637206682067875,
#    'C/H ratio': 0.7335319723742123,
#    'Number of ocean moles': 8.967269585308514},
#   {'fO2_shift': 1.1128330134853899,
#    'C/H ratio': 0.16502437708858889,
#    'Number of ocean moles': 8.476325380539118},
#   {'fO2_shift': 3.1084385105806236,
#    'C/H ratio': 0.7291281359071102,
#    'Number of ocean moles': 5.688622329971962},
#   {'fO2_shift': 1.4009774292492576,
#    'C/H ratio': 0.6146095447275245,
#    'Number of ocean moles': 5.508729095997826},
#   {'fO2_shift': 2.815043051782135,
#    'C/H ratio': 0.3943902583436214,
#    'Number of ocean moles': 3.9631728916827482},
#   {'fO2_shift': 3.4346535866715993,
#    'C/H ratio': 0.18463899420286678,
#    'Number of ocean moles': 5.372400832686723},
#   {'fO2_shift': 1.759091496292183,
#    'C/H ratio': 0.8513012206163277,
#    'Number of ocean moles': 9.317050048419189},
#   {'fO2_shift': 0.8738990648635285,
#    'C/H ratio': 0.6308618290688504,
#    'Number of ocean moles': 2.4992363456295017},
#   {'fO2_shift': -0.08761000476282543,
#    'C/H ratio': 0.9771956660638988,
#    'Number of ocean moles': 7.550378049655986},
#   {'fO2_shift': 2.50908089578484,
#    'C/H ratio': 0.29523680925912366,
#    'Number of ocean moles': 7.820365167956968},
#   {'fO2_shift': 0.7019870188059834,
#    'C/H ratio': 0.8520486721456618,
#    'Number of ocean moles': 1.5063952822704532},
#   {'fO2_shift': 2.968563699207528,
#    'C/H ratio': 0.24812260548370185,
#    'Number of ocean moles': 2.3670514440902104},
#   {'fO2_shift': 1.6447907539229352,
#    'C/H ratio': 0.5541182050148673,
#    'Number of ocean moles': 9.305826112896693},
#   {'fO2_shift': 0.628462984601077,
#    'C/H ratio': 0.60854762070655,
#    'Number of ocean moles': 4.86765623966164},
#   {'fO2_shift': 1.5596225284511602,
#    'C/H ratio': 0.8399936884404337,
#    'Number of ocean moles': 4.999227623858804},
#   {'fO2_shift': -2.8572048980422675,
#    'C/H ratio': 0.22541659574778738,
#    'Number of ocean moles': 1.1267962524464419},
#   {'fO2_shift': -1.5569542900903963,
#    'C/H ratio': 0.5569342243878862,
#    'Number of ocean moles': 3.999647692804008},
#   {'fO2_shift': 2.0775384900195935,
#    'C/H ratio': 0.8857373969798944,
#    'Number of ocean moles': 1.5960150436912395},
#   {'fO2_shift': -2.231566846728663,
#    'C/H ratio': 0.22165147428615645,
#    'Number of ocean moles': 1.0895837142878455},
#   {'fO2_shift': 1.124958319475497,
#    'C/H ratio': 0.7672961089454422,
#    'Number of ocean moles': 8.456324078636932},
#   {'fO2_shift': -2.3472170694533716,
#    'C/H ratio': 0.32488407475526926,
#    'Number of ocean moles': 8.05055620757064},
#   {'fO2_shift': -2.468951042435445,
#    'C/H ratio': 0.4596019190687508,
#    'Number of ocean moles': 9.590606920760242},
#   {'fO2_shift': -2.497086258802897,
#    'C/H ratio': 0.9464393584787665,
#    'Number of ocean moles': 6.732478451275986},
#   {'fO2_shift': -3.667725610648743,
#    'C/H ratio': 0.35389991869150317,
#    'Number of ocean moles': 2.86590236042865},
#   {'fO2_shift': 1.3935914818450756,
#    'C/H ratio': 0.3082879060264494,
#    'Number of ocean moles': 9.006900179150819},
#   {'fO2_shift': 3.076881392161039,
#    'C/H ratio': 0.11738855105565092,
#    'Number of ocean moles': 3.9713542303841574},
#   {'fO2_shift': -2.7646451971651524,
#    'C/H ratio': 0.33657397506700204,
#    'Number of ocean moles': 9.769378238104643},
#   {'fO2_shift': 1.9788209402381893,
#    'C/H ratio': 0.12337497458578543,
#    'Number of ocean moles': 6.158249898742108},
#   {'fO2_shift': -3.900528590327216,
#    'C/H ratio': 0.255057602815557,
#    'Number of ocean moles': 2.9052324466545203},
#   {'fO2_shift': 1.5697312888821155,
#    'C/H ratio': 0.44838172370055296,
#    'Number of ocean moles': 4.5398959780842425},
#   {'fO2_shift': -3.848776184593138,
#    'C/H ratio': 0.5275474043888535,
#    'Number of ocean moles': 3.7046719782989888},
#   {'fO2_shift': 3.613810105766831,
#    'C/H ratio': 0.6415232017866682,
#    'Number of ocean moles': 5.968773003398032},
#   {'fO2_shift': 3.138434251047177,
#    'C/H ratio': 0.5261985835425038,
#    'Number of ocean moles': 8.784941707780948},
#   {'fO2_shift': 2.127770414834834,
#    'C/H ratio': 0.4584442416104849,
#    'Number of ocean moles': 2.7933824264648064},
#   {'fO2_shift': -0.4762374379119878,
#    'C/H ratio': 0.40534684482490524,
#    'Number of ocean moles': 5.786642170815828},
#   {'fO2_shift': -0.5885673341581015,
#    'C/H ratio': 0.8019664216143044,
#    'Number of ocean moles': 9.213739242157047},
#   {'fO2_shift': -2.5763653809883964,
#    'C/H ratio': 0.17525610079077245,
#    'Number of ocean moles': 7.213180475341323},
#   {'fO2_shift': 0.7143852689300312,
#    'C/H ratio': 0.2797406665798552,
#    'Number of ocean moles': 5.613226191496106},
#   {'fO2_shift': -0.05860884491482565,
#    'C/H ratio': 0.4924429176548064,
#    'Number of ocean moles': 4.556788897284752},
#   {'fO2_shift': -3.2649921945059237,
#    'C/H ratio': 0.8010319301732353,
#    'Number of ocean moles': 5.35348766497398},
#   {'fO2_shift': 2.0855565456497835,
#    'C/H ratio': 0.6956361910466455,
#    'Number of ocean moles': 3.4227092905572976},
#   {'fO2_shift': 2.425653337646101,
#    'C/H ratio': 0.4909297368369503,
#    'Number of ocean moles': 7.72060154688246},
#   {'fO2_shift': 0.5235717639033348,
#    'C/H ratio': 0.9916093061410615,
#    'Number of ocean moles': 8.597172560721305},
#   {'fO2_shift': 3.7340787042538226,
#    'C/H ratio': 0.42848355903131974,
#    'Number of ocean moles': 3.2288612824399907},
#   {'fO2_shift': -1.4062543055003243,
#    'C/H ratio': 0.22321577691706554,
#    'Number of ocean moles': 3.299956925631432},
#   {'fO2_shift': -3.0831710858627757,
#    'C/H ratio': 0.1378312114556981,
#    'Number of ocean moles': 3.2554498974497963},
#   {'fO2_shift': 0.8517157936796869,
#    'C/H ratio': 0.37564288999671147,
#    'Number of ocean moles': 4.617775411175502},
#   {'fO2_shift': -1.7930035759091494,
#    'C/H ratio': 0.34043131238102387,
#    'Number of ocean moles': 6.797238732440931},
#   {'fO2_shift': 1.22512739609125,
#    'C/H ratio': 0.6271499535533758,
#    'Number of ocean moles': 4.871706861735619},
#   {'fO2_shift': -0.92919706720037,
#    'C/H ratio': 0.33089383703369357,
#    'Number of ocean moles': 7.1829825033065315},
#   {'fO2_shift': 3.751943471161704,
#    'C/H ratio': 0.9069361969704686,
#    'Number of ocean moles': 5.4201047383981},
#   {'fO2_shift': -2.0843841258862756,
#    'C/H ratio': 0.3590959612647229,
#    'Number of ocean moles': 7.106591297172777},
#   {'fO2_shift': 2.19642245759095,
#    'C/H ratio': 0.10466661894538284,
#    'Number of ocean moles': 1.259818160481448},
#   {'fO2_shift': 3.893225493527903,
#    'C/H ratio': 0.18383872485011632,
#    'Number of ocean moles': 7.374916667579127},
#   {'fO2_shift': 0.10627218001310812,
#    'C/H ratio': 0.7923936790932647,
#    'Number of ocean moles': 9.865185872692479},
#   {'fO2_shift': -1.529501403084434,
#    'C/H ratio': 0.2593040726194491,
#    'Number of ocean moles': 5.590150031295596},
#   {'fO2_shift': 2.39355492803299,
#    'C/H ratio': 0.5434032295145639,
#    'Number of ocean moles': 9.047082970330267},
#   {'fO2_shift': 1.652542741248661,
#    'C/H ratio': 0.2576922090480174,
#    'Number of ocean moles': 3.409458584120283},
#   {'fO2_shift': 2.726970894347109,
#    'C/H ratio': 0.69128011203764,
#    'Number of ocean moles': 7.8600719154694385},
#   {'fO2_shift': -2.177183051048978,
#    'C/H ratio': 0.5483130798796302,
#    'Number of ocean moles': 3.8402988273694527},
#   {'fO2_shift': -0.967412630118214,
#    'C/H ratio': 0.4744991713478084,
#    'Number of ocean moles': 9.317279395418616},
#   {'fO2_shift': -3.5423781458374073,
#    'C/H ratio': 0.40267223296848775,
#    'Number of ocean moles': 7.418046599213284},
#   {'fO2_shift': -3.210352186064269,
#    'C/H ratio': 0.767745411059996,
#    'Number of ocean moles': 9.418856715495497}]}

# %% [markdown]
# We now want to use the simpler system solved above to inform the initial condition for a more complex system. Here, we now include CO2 as a species, although in principle we could include any number of extra species or even remove species compared to the previous species list. Also, we note that the species list does not have to be in the same order as before.

# %%
species: Species = Species()
species.append(GasSpecies(formula='H2O', solubility=PeridotiteH2O()))
species.append(GasSpecies(formula='H2'))
species.append(GasSpecies(formula='O2'))
species.append(GasSpecies(formula='CO'))
species.append(GasSpecies(formula='CO2', solubility=BasaltDixonCO2()))
species.append(GasSpecies(formula='N2', solubility=BasaltLibourelN2()))
species
# Out:
# [13:30:09 - atmodeller.interfaces          - INFO     ] - Creating GasSpecies H2O using thermodynamic data in JANAF (JANAF name = H2O)
# [13:30:09 - atmodeller.interfaces          - INFO     ] - Creating GasSpecies H2 using thermodynamic data in JANAF (JANAF name = H2)
# [13:30:09 - atmodeller.interfaces          - INFO     ] - Creating GasSpecies O2 using thermodynamic data in JANAF (JANAF name = O2)
# [13:30:09 - atmodeller.interfaces          - INFO     ] - Creating GasSpecies CO using thermodynamic data in JANAF (JANAF name = CO)
# [13:30:09 - atmodeller.interfaces          - INFO     ] - Creating GasSpecies CO2 using thermodynamic data in JANAF (JANAF name = CO2)
# [13:30:09 - atmodeller.interfaces          - INFO     ] - Creating GasSpecies N2 using thermodynamic data in JANAF (JANAF name = N2)
# Species([GasSpecies(formula='H2O', thermodynamic_dataset=<atmodeller.interfaces.ThermodynamicDatasetJANAF object at 0x11f12e5d0>, name_in_dataset='H2O', _formula=Formula('H2O'), _thermodynamic_data=ThermodynamicDatasetJANAF.ThermodynamicDataForSpecies(species=..., data_source='JANAF', data=<thermochem.janaf.JanafPhase object at 0x11f14b490>), _output=None, solubility=<atmodeller.solubilities.PeridotiteH2O object at 0x11f12e310>, solid_melt_distribution_coefficient=0, eos=IdealGas(critical_temperature=1, critical_pressure=1, standard_state_pressure=1)),
#          GasSpecies(formula='H2', thermodynamic_dataset=<atmodeller.interfaces.ThermodynamicDatasetJANAF object at 0x11eff5090>, name_in_dataset='H2', _formula=Formula('H2'), _thermodynamic_data=ThermodynamicDatasetJANAF.ThermodynamicDataForSpecies(species=..., data_source='JANAF', data=<thermochem.janaf.JanafPhase object at 0x11f1ce210>), _output=None, solubility=<atmodeller.interfaces.NoSolubility object at 0x11eff4f90>, solid_melt_distribution_coefficient=0, eos=IdealGas(critical_temperature=1, critical_pressure=1, standard_state_pressure=1)),
#          GasSpecies(formula='O2', thermodynamic_dataset=<atmodeller.interfaces.ThermodynamicDatasetJANAF object at 0x11f1cc610>, name_in_dataset='O2', _formula=Formula('O2'), _thermodynamic_data=ThermodynamicDatasetJANAF.ThermodynamicDataForSpecies(species=..., data_source='JANAF', data=<thermochem.janaf.JanafPhase object at 0x11f1ef710>), _output=None, solubility=<atmodeller.interfaces.NoSolubility object at 0x11f1cf0d0>, solid_melt_distribution_coefficient=0, eos=IdealGas(critical_temperature=1, critical_pressure=1, standard_state_pressure=1)),
#          GasSpecies(formula='CO', thermodynamic_dataset=<atmodeller.interfaces.ThermodynamicDatasetJANAF object at 0x11db45010>, name_in_dataset='CO', _formula=Formula('CO'), _thermodynamic_data=ThermodynamicDatasetJANAF.ThermodynamicDataForSpecies(species=..., data_source='JANAF', data=<thermochem.janaf.JanafPhase object at 0x11f181b10>), _output=None, solubility=<atmodeller.interfaces.NoSolubility object at 0x107545a50>, solid_melt_distribution_coefficient=0, eos=IdealGas(critical_temperature=1, critical_pressure=1, standard_state_pressure=1)),
#          GasSpecies(formula='CO2', thermodynamic_dataset=<atmodeller.interfaces.ThermodynamicDatasetJANAF object at 0x11f1a5210>, name_in_dataset='CO2', _formula=Formula('CO2'), _thermodynamic_data=ThermodynamicDatasetJANAF.ThermodynamicDataForSpecies(species=..., data_source='JANAF', data=<thermochem.janaf.JanafPhase object at 0x11f0f6a90>), _output=None, solubility=<atmodeller.solubilities.BasaltDixonCO2 object at 0x11f236050>, solid_melt_distribution_coefficient=0, eos=IdealGas(critical_temperature=1, critical_pressure=1, standard_state_pressure=1)),
#          GasSpecies(formula='N2', thermodynamic_dataset=<atmodeller.interfaces.ThermodynamicDatasetJANAF object at 0x11f0f6990>, name_in_dataset='N2', _formula=Formula('N2'), _thermodynamic_data=ThermodynamicDatasetJANAF.ThermodynamicDataForSpecies(species=..., data_source='JANAF', data=<thermochem.janaf.JanafPhase object at 0x11f268550>), _output=None, solubility=<atmodeller.solubilities.BasaltLibourelN2 object at 0x11f0f6810>, solid_melt_distribution_coefficient=0, eos=IdealGas(critical_temperature=1, critical_pressure=1, standard_state_pressure=1))])

# %% [markdown]
# In the new species list above, we also specify CO2.  Hence in the below we must provide a fill value to use for CO2 because the original data has no notion of CO2. In the below, we set the initial CO2 pressure to 1 bar.

# %%
initial_condition = InitialConditionRegressor.from_pickle('tutorial3b_monte_carlo.pkl', species=species, species_fill={'CO2':1}, fit=True, fit_batch_size=100, partial_fit=True, partial_fit_batch_size=50)
# Out:
# [13:30:12 - atmodeller.output              - INFO     ] - Output: Reading data from tutorial3b_monte_carlo.pkl
# [13:30:12 - atmodeller.initial_condition   - INFO     ] - Creating InitialConditionRegressor
# [13:30:12 - atmodeller.initial_condition   - INFO     ] - InitialConditionRegressor: Fit (None, None)
# [13:30:12 - atmodeller.initial_condition   - INFO     ] - InitialConditionRegressor: Found constraints = ['H_mass', 'C_mass', 'N_mass', 'O2_fugacity']
# [13:30:12 - atmodeller.initial_condition   - INFO     ] - InitialConditionRegressor: Found species = ['H2O', 'H2', 'O2', 'CO', 'CO2', 'N2']

# %% [markdown]
# In the above, fit = True, which means the trained data from the previous run (as computed from the output in the pickle file) is only used for the first fit_batch_size = 100 simulations. Subsequently the regressor will re-train itself on just the (fit_batch_size = 100) samples generated from the current model, discarding knowledge of the previous data it was trained on. Then, every partial_fit_batch_size = 100 simulations, it will update its training with the last batch of newly generated samples in order to better inform the selection of subsequent initial conditions. This is known as a dynamic or online learning approach.
#
# It is necessary to pass the initial condition to the interior atmosphere system when it is created:

# %%
interior_atmosphere_ic: InteriorAtmosphereSystem = InteriorAtmosphereSystem(species=species, initial_condition=initial_condition, planet=planet)
monte_carlo(interior_atmosphere_ic, number_of_realisations=200)
# Out:
# [13:30:20 - atmodeller.interior_atmosphere - INFO     ] - Creating an interior-atmosphere system
# [13:30:20 - atmodeller.interior_atmosphere - INFO     ] - Creating a reaction network
# [13:30:20 - atmodeller.interior_atmosphere - INFO     ] - Species = ['H2O', 'H2', 'O2', 'CO', 'CO2', 'N2']
# [13:30:20 - atmodeller.interior_atmosphere - INFO     ] - Reactions =
# {0: '0.5 O2 + 1.0 CO = 1.0 CO2', 1: '1.0 H2O = 1.0 H2 + 0.5 O2'}
# [13:30:20 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 0
# [13:30:21 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:21 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.1397946481771252
# [13:30:21 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 15.459861225620694,
#  'CO2': 1.0136537475032763,
#  'H2': 3.141347497099219,
#  'H2O': 0.9390766046352297,
#  'N2': 1.9143844250830895,
#  'O2': 7.448211706900744e-09}
# [13:30:21 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 1
# [13:30:21 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:21 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.6445853510774232
# [13:30:21 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 505.5814549756771,
#  'CO2': 36.18624681114094,
#  'H2': 53.32883540740325,
#  'H2O': 17.402654829543625,
#  'N2': 2.0429084594347517,
#  'O2': 8.875416560054875e-09}
# [13:30:21 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 2
# [13:30:22 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:22 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.8200090985912061
# [13:30:22 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 230.65279180089496,
#  'CO2': 100.84419865306037,
#  'H2': 3.5298918212414994,
#  'H2O': 7.036466115402558,
#  'N2': 2.4687722633976845,
#  'O2': 3.31183233035557e-07}
# [13:30:22 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 3
# [13:30:22 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:22 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.13603643950305588
# [13:30:22 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 90.2025449365293,
#  'CO2': 1.8306582658683235,
#  'H2': 108.43390103265307,
#  'H2O': 10.033548943435031,
#  'N2': 1.1319337736997728,
#  'O2': 7.136099791013337e-10}
# [13:30:22 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 4
# [13:30:23 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:23 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.16075769917289373
# [13:30:23 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 67.05770821434164,
#  'CO2': 1.8189955821569637,
#  'H2': 16.055937349626788,
#  'H2O': 1.985727285509112,
#  'N2': 1.8180745116616173,
#  'O2': 1.2748227621429343e-09}
# [13:30:23 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 5
# [13:30:23 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:23 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.7833660303540615
# [13:30:23 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 76.24317963298414,
#  'CO2': 79.5304149650166,
#  'H2': 1.0765774687526986,
#  'H2O': 5.12010109570238,
#  'N2': 2.6876739750549654,
#  'O2': 1.8851609353619355e-06}
# [13:30:23 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 6
# [13:30:23 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:23 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.987590630457431
# [13:30:23 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 174.91398737025173,
#  'CO2': 248.78401758192976,
#  'H2': 2.504480659607675,
#  'H2O': 16.241144114856077,
#  'N2': 2.7723689442527046,
#  'O2': 3.5049337043840722e-06}
# [13:30:23 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 7
# [13:30:24 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:24 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.1348231717176976
# [13:30:24 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 28.9643922954617,
#  'CO2': 1.5761656706228262,
#  'H2': 1.7259739678287287,
#  'H2O': 0.42822565804357066,
#  'N2': 2.1096276545710873,
#  'O2': 5.1304897076978834e-09}
# [13:30:24 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 8
# [13:30:24 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:24 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.2782371192201596
# [13:30:24 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 168.75522314902517,
#  'CO2': 4.468240012124215,
#  'H2': 157.97561022019832,
#  'H2O': 19.070861507420005,
#  'N2': 1.2577953187725381,
#  'O2': 1.2146257211283394e-09}
# [13:30:24 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 9
# [13:30:24 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:24 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 1.157049554617379
# [13:30:24 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 18.14401304641771,
#  'CO2': 310.9019778609826,
#  'H2': 0.09722825038192394,
#  'H2O': 7.595976406768178,
#  'N2': 3.195105442311568,
#  'O2': 0.0005087028901309875}
# [13:30:25 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 10
# [13:30:25 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:25 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.12743795922844345
# [13:30:25 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 285.16915633556704,
#  'CO2': 1.9011179522763617,
#  'H2': 448.68864490205834,
#  'H2O': 13.638059850332128,
#  'N2': 0.9689609872127556,
#  'O2': 7.700110516673824e-11}
# [13:30:25 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 11
# [13:30:25 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:25 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.7790651845301771
# [13:30:25 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 138.83720216838344,
#  'CO2': 77.91446268917214,
#  'H2': 6.948369631773689,
#  'H2O': 17.77854197138666,
#  'N2': 2.427383750080031,
#  'O2': 5.456427484594869e-07}
# [13:30:25 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 12
# [13:30:26 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:26 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 1.0759107320797083
# [13:30:26 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 106.73121095770203,
#  'CO2': 362.70644216588295,
#  'H2': 0.8696692435591181,
#  'H2O': 13.47469502987303,
#  'N2': 2.997688557428985,
#  'O2': 2.0008364893776384e-05}
# [13:30:26 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 13
# [13:30:26 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:26 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.17125516966036738
# [13:30:26 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 23.379670195098345,
#  'CO2': 0.5021521914508503,
#  'H2': 22.043394899571854,
#  'H2O': 2.158621328382282,
#  'N2': 1.2676204780728149,
#  'O2': 7.992412638705923e-10}
# [13:30:26 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 14
# [13:30:26 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:26 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.49318217442484924
# [13:30:26 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 23.981416554558944,
#  'CO2': 0.07676881884641272,
#  'H2': 167.42639603630738,
#  'H2O': 2.443627228937383,
#  'N2': 0.433861848315322,
#  'O2': 1.7754317658376018e-11}
# [13:30:26 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 15
# [13:30:27 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:27 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.5353367418758126
# [13:30:27 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 17.39089686840958,
#  'CO2': 18.873133021960992,
#  'H2': 0.2874476821102563,
#  'H2O': 1.4222692917490247,
#  'N2': 2.6625597112003234,
#  'O2': 2.0404594889698385e-06}
# [13:30:27 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 16
# [13:30:27 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:27 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.580741586426452
# [13:30:27 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 246.06596045490198,
#  'CO2': 25.249438111208892,
#  'H2': 20.349155585495748,
#  'H2O': 9.52023287060679,
#  'N2': 2.1074520086260744,
#  'O2': 1.8242497304624684e-08}
# [13:30:27 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 17
# [13:30:27 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:27 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.36599737686665323
# [13:30:27 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 51.12707120029122,
#  'CO2': 0.183115142474853,
#  'H2': 327.1791156473993,
#  'H2O': 5.342689307069562,
#  'N2': 0.4542825699608786,
#  'O2': 2.2224429560344018e-11}
# [13:30:27 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 18
# [13:30:28 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:28 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.4459705515747196
# [13:30:28 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 47.70603196859037,
#  'CO2': 11.183235962459971,
#  'H2': 4.9561120511701695,
#  'H2O': 5.297077307744696,
#  'N2': 2.1582404974471303,
#  'O2': 9.52077542961362e-08}
# [13:30:28 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 19
# [13:30:28 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:28 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.564429702132031
# [13:30:28 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 77.98104749735866,
#  'CO2': 23.44035596861271,
#  'H2': 0.5923519876390121,
#  'H2O': 0.8118129765847717,
#  'N2': 2.40542409860016,
#  'O2': 1.5654320106899424e-07}
# [13:30:28 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 20
# [13:30:28 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:28 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.403471558020419
# [13:30:28 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 38.42270948318233,
#  'CO2': 0.15754375235990062,
#  'H2': 335.117552700406,
#  'H2O': 6.2648600672055,
#  'N2': 0.3931053400583006,
#  'O2': 2.912797750521812e-11}
# [13:30:28 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 21
# [13:30:29 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:29 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 1.082361491363404
# [13:30:29 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 8.240801074746063,
#  'CO2': 169.36857891851056,
#  'H2': 0.12005918506063311,
#  'H2O': 11.250188648119284,
#  'N2': 3.132049422366569,
#  'O2': 0.0007318309288700896}
# [13:30:29 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 22
# [13:30:29 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:29 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.33051177370177076
# [13:30:29 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 33.48819911914301,
#  'CO2': 0.16527263468930337,
#  'H2': 116.52902894604077,
#  'H2O': 2.6220700239156085,
#  'N2': 0.6412761214501056,
#  'O2': 4.219900864859964e-11}
# [13:30:29 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 23
# [13:30:30 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:30 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.830648837429589
# [13:30:30 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 74.49398368967724,
#  'CO2': 101.06253826110593,
#  'H2': 0.37036422146700926,
#  'H2O': 2.2908625296921685,
#  'N2': 2.795481024317801,
#  'O2': 3.188760770586415e-06}
# [13:30:30 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 24
# [13:30:30 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:30 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.22294843171241097
# [13:30:30 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 19.533971582920493,
#  'CO2': 0.41108176528402135,
#  'H2': 62.263629094455105,
#  'H2O': 5.974108317532931,
#  'N2': 0.7329677243157346,
#  'O2': 7.6728950275008e-10}
# [13:30:30 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 25
# [13:30:30 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:30 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 1.058495729563241
# [13:30:30 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 147.91183333641118,
#  'CO2': 351.11030123086493,
#  'H2': 1.7166518824072396,
#  'H2O': 18.579066381768982,
#  'N2': 2.9067910914598363,
#  'O2': 9.762594187437223e-06}
# [13:30:30 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 26
# [13:30:31 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:31 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.35039527665040765
# [13:30:31 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 13.574541262443768,
#  'CO2': 0.16496379173146156,
#  'H2': 48.37821951144232,
#  'H2O': 2.6804909804827575,
#  'N2': 0.6710379440832123,
#  'O2': 2.5586499332390554e-10}
# [13:30:31 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 27
# [13:30:31 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:31 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.27093676966379254
# [13:30:31 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 68.01551085635009,
#  'CO2': 0.222488343360854,
#  'H2': 116.98947096487161,
#  'H2O': 1.7448057188928545,
#  'N2': 0.9109638247419238,
#  'O2': 1.8538838884057347e-11}
# [13:30:31 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 28
# [13:30:31 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:31 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 1.0812293416590126
# [13:30:31 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 100.90221838569005,
#  'CO2': 367.86035046540803,
#  'H2': 0.7353601168010313,
#  'H2O': 12.22315554609666,
#  'N2': 3.015506458038365,
#  'O2': 2.3027588799107322e-05}
# [13:30:31 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 29
# [13:30:32 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:32 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 1.0302651436872774
# [13:30:32 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 50.25504648287548,
#  'CO2': 248.28992114977973,
#  'H2': 0.2203228840466798,
#  'H2O': 4.9629513783996,
#  'N2': 3.0802299150721604,
#  'O2': 4.229049391117675e-05}
# [13:30:32 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 30
# [13:30:32 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:32 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.29712391634250246
# [13:30:32 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 74.14529653426763,
#  'CO2': 0.20120861629587802,
#  'H2': 168.4704655455899,
#  'H2O': 2.084432063500631,
#  'N2': 0.7821515496156767,
#  'O2': 1.2758801190807488e-11}
# [13:30:32 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 31
# [13:30:32 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:32 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.938603299640643
# [13:30:32 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 354.3032812109679,
#  'CO2': 196.61539546517616,
#  'H2': 7.465946826403619,
#  'H2O': 18.889838299446602,
#  'N2': 2.508821724008554,
#  'O2': 5.335420188686522e-07}
# [13:30:32 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 32
# [13:30:33 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:33 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.256096404833514
# [13:30:33 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 114.70476525982677,
#  'CO2': 3.7047618569330685,
#  'H2': 70.52590667609957,
#  'H2O': 10.385526430486987,
#  'N2': 1.46132844317468,
#  'O2': 1.8073472663912085e-09}
# [13:30:33 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 33
# [13:30:33 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:33 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.9504117344721463
# [13:30:33 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 31.582393927077916,
#  'CO2': 155.53092230445486,
#  'H2': 0.31493178988311343,
#  'H2O': 7.071136220088283,
#  'N2': 3.0400542223638514,
#  'O2': 4.201722212587715e-05}
# [13:30:33 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 34
# [13:30:33 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:33 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.18667430777878835
# [13:30:33 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 50.9880878707244,
#  'CO2': 0.3578849377341235,
#  'H2': 108.15443051200639,
#  'H2O': 3.4611467304158086,
#  'N2': 0.8422188294749077,
#  'O2': 8.53558564558593e-11}
# [13:30:33 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 35
# [13:30:34 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:34 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.36526624568182586
# [13:30:34 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 16.012596222810853,
#  'CO2': 7.350812718070561,
#  'H2': 0.4860587997144645,
#  'H2O': 1.017333666195121,
#  'N2': 2.415267467606666,
#  'O2': 3.651162357406997e-07}
# [13:30:34 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 36
# [13:30:34 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:34 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.9459487768586005
# [13:30:34 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 12.895220650005921,
#  'CO2': 112.74796974436902,
#  'H2': 0.02609765278742015,
#  'H2O': 1.0403570208776416,
#  'N2': 3.153251246823121,
#  'O2': 0.00013244752257772168}
# [13:30:34 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 37
# [13:30:35 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:35 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.10264573113429667
# [13:30:35 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 60.41693173187645,
#  'CO2': 0.8678765741804344,
#  'H2': 36.90680950127023,
#  'H2O': 2.417167822785418,
#  'N2': 1.4468761924747597,
#  'O2': 3.575053410367608e-10}
# [13:30:35 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 38
# [13:30:35 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:35 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.2981264984164683
# [13:30:35 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 22.245452707308676,
#  'CO2': 0.29734570877964267,
#  'H2': 202.33385815042632,
#  'H2O': 12.330764141521536,
#  'N2': 0.4306798919800646,
#  'O2': 3.0954570900450256e-10}
# [13:30:35 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 39
# [13:30:35 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:35 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 1.0054253446215882
# [13:30:35 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 34.95310486006659,
#  'CO2': 203.17703353388407,
#  'H2': 0.686234530697281,
#  'H2O': 18.18705683092363,
#  'N2': 3.007325409911228,
#  'O2': 5.8541203271214105e-05}
# [13:30:35 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 40
# [13:30:36 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:36 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.9426097455341185
# [13:30:36 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 87.79386890057766,
#  'CO2': 183.0752124514307,
#  'H2': 1.3925007091331976,
#  'H2O': 13.23920127834039,
#  'N2': 2.853990679292262,
#  'O2': 7.5338098034141905e-06}
# [13:30:36 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 41
# [13:30:36 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:36 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.874315633863486
# [13:30:36 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 6.151812865466065,
#  'CO2': 65.2174041998344,
#  'H2': 0.03441396030120107,
#  'H2O': 1.6633975110286816,
#  'N2': 3.1292717236045196,
#  'O2': 0.00019471738120886}
# [13:30:36 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 42
# [13:30:37 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:37 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.8874886916833655
# [13:30:37 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 5.882164618867481,
#  'CO2': 64.54900084740818,
#  'H2': 0.0073019697342110446,
#  'H2O': 0.36533676530674525,
#  'N2': 3.1606461073744567,
#  'O2': 0.00020863570492653962}
# [13:30:37 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 43
# [13:30:37 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:37 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 1.1381341948718033
# [13:30:37 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 27.485113406526512,
#  'CO2': 334.9562450732745,
#  'H2': 0.20482300116284788,
#  'H2O': 11.380733992738339,
#  'N2': 3.159349502237081,
#  'O2': 0.00025731495416087604}
# [13:30:37 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 44
# [13:30:37 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:37 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.1823816657523167
# [13:30:37 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 135.61576573100254,
#  'CO2': 2.1808994852465835,
#  'H2': 38.10236004627994,
#  'H2O': 2.7936908609423976,
#  'N2': 1.7517803810427859,
#  'O2': 4.4805865744950354e-10}
# [13:30:37 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 45
# [13:30:38 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:38 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.6602354405941191
# [13:30:38 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 52.169867236375964,
#  'CO2': 40.11035253574373,
#  'H2': 0.8532768381452903,
#  'H2O': 2.9910777734786236,
#  'N2': 2.59605463732334,
#  'O2': 1.0241355207952063e-06}
# [13:30:38 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 46
# [13:30:38 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:38 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.569507291175668
# [13:30:38 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 202.13633098543565,
#  'CO2': 23.90260387181565,
#  'H2': 9.134090333861444,
#  'H2O': 4.924556664769634,
#  'N2': 2.1899851030613537,
#  'O2': 2.4226217144241682e-08}
# [13:30:38 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 47
# [13:30:39 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:39 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.828660704131294
# [13:30:39 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 12.01360636949789,
#  'CO2': 64.52751971874264,
#  'H2': 0.010597376209416153,
#  'H2O': 0.25952005667678657,
#  'N2': 3.0885389122640867,
#  'O2': 4.9983548232793004e-05}
# [13:30:39 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 48
# [13:30:39 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:39 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 1.0042470559703773
# [13:30:39 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 17.717476580523225,
#  'CO2': 165.02416364613612,
#  'H2': 0.24430538972449084,
#  'H2O': 10.374799735278422,
#  'N2': 3.08815476133581,
#  'O2': 0.00015030564107412796}
# [13:30:39 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 49
# [13:30:39 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:39 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.8539139239728495
# [13:30:39 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 332.31982697456806,
#  'CO2': 122.09953909946562,
#  'H2': 6.973400951798057,
#  'H2O': 11.681628999125808,
#  'N2': 2.4157087584176202,
#  'O2': 2.3388344233208233e-07}
# [13:30:39 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 50
# [13:30:40 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:40 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.21929146907080904
# [13:30:40 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 50.42799783520497,
#  'CO2': 0.29321438116193055,
#  'H2': 84.9654571381908,
#  'H2O': 2.2524592410833884,
#  'N2': 0.9406604697817992,
#  'O2': 5.85748273898716e-11}
# [13:30:40 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 51
# [13:30:40 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:40 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.8035122486469395
# [13:30:40 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 99.80100366689332,
#  'CO2': 88.66505871696793,
#  'H2': 0.4046127244178421,
#  'H2O': 1.6389214326734878,
#  'N2': 2.6845508902148945,
#  'O2': 1.3674741596984085e-06}
# [13:30:40 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 52
# [13:30:40 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:40 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.6139098306617522
# [13:30:40 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 207.9753359528713,
#  'CO2': 30.970585432648445,
#  'H2': 7.675978836874193,
#  'H2O': 5.211615295866925,
#  'N2': 2.2315026364638015,
#  'O2': 3.842015343097005e-08}
# [13:30:40 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 53
# [13:30:41 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:41 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.5108962069604556
# [13:30:41 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 249.205685079971,
#  'CO2': 16.741087043012342,
#  'H2': 29.992864129466664,
#  'H2O': 9.186385155596959,
#  'N2': 2.015594051206847,
#  'O2': 7.818714442619897e-09}
# [13:30:41 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 54
# [13:30:41 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:41 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 1.021058792608674
# [13:30:41 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 10.576744083448222,
#  'CO2': 146.72539137570178,
#  'H2': 0.10830643209190888,
#  'H2O': 6.85028327048228,
#  'N2': 3.1386479541571983,
#  'O2': 0.000333419115464124}
# [13:30:41 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 55
# [13:30:41 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:41 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.6775038445922793
# [13:30:41 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 187.20805231936302,
#  'CO2': 44.73229824406682,
#  'H2': 6.434892017442225,
#  'H2O': 7.010337896603129,
#  'N2': 2.302695062372177,
#  'O2': 9.891845121140965e-08}
# [13:30:41 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 56
# [13:30:42 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:42 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.5784043615757161
# [13:30:42 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 6.953001876719869,
#  'CO2': 0.05429005977941358,
#  'H2': 123.5620575723606,
#  'H2O': 4.398798880952726,
#  'N2': 0.316479844424116,
#  'O2': 1.0562820039936697e-10}
# [13:30:42 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 57
# [13:30:42 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:42 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 1.1885573885310177
# [13:30:42 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 28.334421700005823,
#  'CO2': 418.39490274685875,
#  'H2': 0.28644685837500766,
#  'H2O': 19.28488690043156,
#  'N2': 3.1551617475556895,
#  'O2': 0.0003777704623484138}
# [13:30:42 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 58
# [13:30:43 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:43 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.47848250529827213
# [13:30:43 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 465.0969489086913,
#  'CO2': 13.959503306791017,
#  'H2': 155.3256337903624,
#  'H2O': 21.255465023791054,
#  'N2': 1.7043163179926064,
#  'O2': 1.5607627272444216e-09}
# [13:30:43 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 59
# [13:30:43 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:43 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.7929004022107308
# [13:30:43 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 138.23307658504237,
#  'CO2': 83.64704810182114,
#  'H2': 7.962856566571469,
#  'H2O': 21.968911497953545,
#  'N2': 2.4233445275706127,
#  'O2': 6.343971523912714e-07}
# [13:30:43 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 60
# [13:30:43 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:43 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.438789074805384
# [13:30:43 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 85.14712402387227,
#  'CO2': 11.397907792876454,
#  'H2': 2.1068886284797577,
#  'H2O': 1.2858719888623062,
#  'N2': 2.2433977994745136,
#  'O2': 3.10451845321324e-08}
# [13:30:43 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 61
# [13:30:44 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:44 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 1.0141652571958328
# [13:30:44 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 431.0664917619241,
#  'CO2': 300.31173972194944,
#  'H2': 8.022656511391592,
#  'H2O': 25.48280578226017,
#  'N2': 2.573261095243118,
#  'O2': 8.408916189708744e-07}
# [13:30:44 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 62
# [13:30:44 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:44 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.40693655539007195
# [13:30:44 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 51.66775876129435,
#  'CO2': 9.580706937241054,
#  'H2': 0.6756906489919751,
#  'H2O': 0.5712508276979823,
#  'N2': 2.308115130246611,
#  'O2': 5.957167335079969e-08}
# [13:30:44 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 63
# [13:30:44 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:44 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.40091231655838583
# [13:30:44 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 25.619016096967925,
#  'CO2': 9.301135382951188,
#  'H2': 0.17222398158257954,
#  'H2O': 0.28508091599784235,
#  'N2': 2.4346183451908923,
#  'O2': 2.28365751660702e-07}
# [13:30:44 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 64
# [13:30:45 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:45 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.31701112658507735
# [13:30:45 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 268.67330478615736,
#  'CO2': 5.297900015773335,
#  'H2': 74.89558317169308,
#  'H2O': 6.733431529731942,
#  'N2': 1.756942361124061,
#  'O2': 6.736625660340501e-10}
# [13:30:45 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 65
# [13:30:45 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:45 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 1.0068967860293216
# [13:30:45 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 15.578858065471591,
#  'CO2': 158.21252663020772,
#  'H2': 0.3991536163105587,
#  'H2O': 18.481887184861353,
#  'N2': 3.021713184741194,
#  'O2': 0.00017868760398554899}
# [13:30:45 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 66
# [13:30:46 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:46 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.8146759558363577
# [13:30:46 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 100.03747678341296,
#  'CO2': 95.71952040802265,
#  'H2': 1.0279499985950011,
#  'H2O': 4.48446641812471,
#  'N2': 2.681293465219691,
#  'O2': 1.586205691763831e-06}
# [13:30:46 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 67
# [13:30:46 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:46 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.4424050625874679
# [13:30:46 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 26.309545590752812,
#  'CO2': 0.08317300346133243,
#  'H2': 60.49031000910823,
#  'H2O': 0.87187825974415,
#  'N2': 0.790861797756028,
#  'O2': 1.7314980589778367e-11}
# [13:30:46 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 68
# [13:30:46 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:46 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 1.1316603618109526
# [13:30:46 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 18.625717351367715,
#  'CO2': 284.2054434985223,
#  'H2': 0.3637031860156765,
#  'H2O': 25.302736347247066,
#  'N2': 3.0911132914958057,
#  'O2': 0.0004033877464082636}
# [13:30:46 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 69
# [13:30:47 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:47 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.6559174366797582
# [13:30:47 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 298.16019041886676,
#  'CO2': 38.854428575278625,
#  'H2': 25.729847714317383,
#  'H2O': 15.287240076713971,
#  'N2': 2.122294182022385,
#  'O2': 2.9421558387891702e-08}
# [13:30:47 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 70
# [13:30:47 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:47 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.5510139205782909
# [13:30:47 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 27.36535660679875,
#  'CO2': 21.451735194392626,
#  'H2': 0.15808466429270845,
#  'H2O': 0.5650046962850938,
#  'N2': 2.6262440482564924,
#  'O2': 1.0646492803988716e-06}
# [13:30:47 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 71
# [13:30:47 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:47 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.570662273722842
# [13:30:47 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 78.51995176996643,
#  'CO2': 23.80500748990056,
#  'H2': 4.757523484322271,
#  'H2O': 6.5761277303281815,
#  'N2': 2.2822893462389082,
#  'O2': 1.5924306602656583e-07}
# [13:30:47 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 72
# [13:30:48 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:48 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.04595873484544041
# [13:30:48 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 149.16447500297224,
#  'CO2': 1.0655642865039332,
#  'H2': 325.2401413334721,
#  'H2O': 10.593010297401502,
#  'N2': 0.8263751079503319,
#  'O2': 8.841224914503442e-11}
# [13:30:48 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 73
# [13:30:48 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:48 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.9675416825926837
# [13:30:48 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 172.58963784897014,
#  'CO2': 223.61152756649324,
#  'H2': 2.6443236789812397,
#  'H2O': 15.620505567342466,
#  'N2': 2.7442344087791737,
#  'O2': 2.9083245959870468e-06}
# [13:30:48 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 74
# [13:30:48 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:48 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.4367304153730928
# [13:30:48 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 14.627978992130771,
#  'CO2': 0.11533717682997076,
#  'H2': 143.62838536592167,
#  'H2O': 5.163287026368233,
#  'N2': 0.3943158162653134,
#  'O2': 1.0770947568067922e-10}
# [13:30:48 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 75
# [13:30:49 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:49 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.5229727317130236
# [13:30:49 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 7.723513271248918,
#  'CO2': 15.275638967399184,
#  'H2': 0.14228183370463857,
#  'H2O': 1.283024480822585,
#  'N2': 2.7688520043608182,
#  'O2': 6.777240709730639e-06}
# [13:30:49 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 76
# [13:30:49 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:49 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.3185197359598814
# [13:30:49 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 53.27179160666746,
#  'CO2': 5.259805401866596,
#  'H2': 7.559070794797908,
#  'H2O': 3.402842024112961,
#  'N2': 2.009890735018583,
#  'O2': 1.6889962362624485e-08}
# [13:30:49 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 77
# [13:30:50 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:50 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 1.202340739678637
# [13:30:50 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 18.46913174117458,
#  'CO2': 374.7527477833579,
#  'H2': 0.08302459648720449,
#  'H2O': 7.680794068478549,
#  'N2': 3.211668419213691,
#  'O2': 0.0007133138026165474}
# [13:30:50 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 78
# [13:30:50 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:50 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.4982470335891012
# [13:30:50 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 80.16493699066288,
#  'CO2': 14.848970746915416,
#  'H2': 15.360330684533174,
#  'H2O': 12.972194826995038,
#  'N2': 1.9895585685818713,
#  'O2': 5.9443959067317635e-08}
# [13:30:50 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 79
# [13:30:50 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:50 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.502490278221491
# [13:30:50 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 129.47972573565846,
#  'CO2': 15.987868102830962,
#  'H2': 12.708044290481494,
#  'H2O': 7.1543223931185,
#  'N2': 2.0967587469303126,
#  'O2': 2.641566243371009e-08}
# [13:30:50 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 80
# [13:30:51 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:51 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 1.0132828494628991
# [13:30:51 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 60.30936749650221,
#  'CO2': 240.02600332171448,
#  'H2': 0.3079424282566636,
#  'H2O': 5.587841143088772,
#  'N2': 3.040962552357149,
#  'O2': 2.744296136277064e-05}
# [13:30:51 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 81
# [13:30:51 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:51 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.23340329068607513
# [13:30:51 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 82.26927155543075,
#  'CO2': 3.119500561281335,
#  'H2': 5.132576669498851,
#  'H2O': 0.8873273393462024,
#  'N2': 2.0867139124219123,
#  'O2': 2.4910289030003548e-09}
# [13:30:51 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 82
# [13:30:51 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:51 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.8192788999274502
# [13:30:51 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 20.223749909247545,
#  'CO2': 72.70813410975595,
#  'H2': 0.02291994031807162,
#  'H2O': 0.3756953302475288,
#  'N2': 3.0280216354346727,
#  'O2': 2.2393736375315343e-05}
# [13:30:51 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 83
# [13:30:52 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:52 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.8524328863686331
# [13:30:52 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 23.897628766088353,
#  'CO2': 90.8063899585707,
#  'H2': 0.05283189098873958,
#  'H2O': 0.9152900824299136,
#  'N2': 3.036691568587375,
#  'O2': 2.5015381725700745e-05}
# [13:30:52 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 84
# [13:30:52 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:52 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.9210099071275984
# [13:30:52 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 228.9505520993497,
#  'CO2': 176.16543636950084,
#  'H2': 5.544294113959257,
#  'H2O': 19.450298488882122,
#  'N2': 2.578643923170288,
#  'O2': 1.0257510065206349e-06}
# [13:30:52 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 85
# [13:30:53 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:53 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.2813689474553903
# [13:30:53 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 94.60451732184562,
#  'CO2': 4.19699589560825,
#  'H2': 28.31596135575769,
#  'H2O': 5.727419347130578,
#  'N2': 1.7599201211498723,
#  'O2': 3.409865702907542e-09}
# [13:30:53 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 86
# [13:30:53 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:53 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.5694068490024233
# [13:30:53 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 128.72391728380254,
#  'CO2': 24.140513213115007,
#  'H2': 2.0519392268106356,
#  'H2O': 1.754497469081396,
#  'N2': 2.306465007491692,
#  'O2': 6.093382436488029e-08}
# [13:30:53 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 87
# [13:30:53 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:53 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.48802151856243736
# [13:30:53 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 132.1331972069008,
#  'CO2': 14.937890757644816,
#  'H2': 7.259451031089936,
#  'H2O': 3.741813318439997,
#  'N2': 2.1668398401363347,
#  'O2': 2.2143109363853336e-08}
# [13:30:53 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 88
# [13:30:54 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:54 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.3287928060616819
# [13:30:54 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 29.947849044155955,
#  'CO2': 0.1631601186501048,
#  'H2': 31.171689154640752,
#  'H2O': 0.7743008123996142,
#  'N2': 1.1778259763458632,
#  'O2': 5.1425756421478943e-11}
# [13:30:54 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 89
# [13:30:54 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:54 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.2442120084463544
# [13:30:54 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 32.74096089558496,
#  'CO2': 0.26489993123175276,
#  'H2': 72.84791343038479,
#  'H2O': 2.687252912909437,
#  'N2': 0.8293212094313598,
#  'O2': 1.1341350780230561e-10}
# [13:30:54 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 90
# [13:30:54 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:54 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.9988105786370859
# [13:30:54 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 119.24650254016284,
#  'CO2': 252.79583271701645,
#  'H2': 1.8691880793377769,
#  'H2O': 18.06667632228042,
#  'N2': 2.860377391519744,
#  'O2': 7.78632370085883e-06}
# [13:30:54 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 91
# [13:30:55 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:30:55 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.4942956269430663
# ...
# [13:31:21 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 140.7316439846159,
#  'CO2': 22.29049402592665,
#  'H2': 2.0641570400739306,
#  'H2O': 1.4906362178850683,
#  'N2': 2.2861232793734976,
#  'O2': 4.346501161398289e-08}
# [13:31:21 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 170
# [13:31:22 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:31:22 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.15996054434413645
# [13:31:22 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 164.78600467523793,
#  'CO2': 127.14157937890033,
#  'H2': 1.4505455768803466,
#  'H2O': 5.10269556014168,
#  'N2': 2.6311832839429217,
#  'O2': 1.031379487974807e-06}
# [13:31:22 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 171
# [13:31:22 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:31:22 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.13066110589162488
# [13:31:22 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 25.691549030372784,
#  'CO2': 1.1513816674084454,
#  'H2': 28.08155144940618,
#  'H2O': 5.73787547897464,
#  'N2': 1.2277497199581058,
#  'O2': 3.479701372019257e-09}
# [13:31:22 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 172
# [13:31:22 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:31:22 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.18512917168772364
# [13:31:22 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 148.2860335942878,
#  'CO2': 98.24843238013315,
#  'H2': 4.212399560794274,
#  'H2O': 12.724945788297045,
#  'N2': 2.527230026001841,
#  'O2': 7.605621282001255e-07}
# [13:31:22 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 173
# [13:31:23 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:31:23 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.23554001820292317
# [13:31:23 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 14.353810024255965,
#  'CO2': 0.4314723610055195,
#  'H2': 98.8600916984664,
#  'H2O': 13.549017296743838,
#  'N2': 0.5506977744743335,
#  'O2': 1.5655087835707324e-09}
# [13:31:23 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 174
# [13:31:23 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:31:23 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.19730490846824997
# [13:31:23 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 12.697964250918455,
#  'CO2': 0.3697055172869329,
#  'H2': 49.973308349262894,
#  'H2O': 6.633778011409147,
#  'N2': 0.6926736806239904,
#  'O2': 1.46868140977259e-09}
# [13:31:23 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 175
# [13:31:23 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:31:23 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.21595325057871687
# [13:31:23 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 228.16108038713676,
#  'CO2': 71.62008903005774,
#  'H2': 16.657227618063086,
#  'H2O': 23.839492908457544,
#  'N2': 2.262843823508269,
#  'O2': 1.7071454229600012e-07}
# [13:31:23 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 176
# [13:31:24 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:31:24 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.3250183650813929
# [13:31:24 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 17.43083378080442,
#  'CO2': 355.6767521768815,
#  'H2': 0.1136664476105131,
#  'H2O': 10.574762115426255,
#  'N2': 3.196630955897006,
#  'O2': 0.0007213708195488658}
# [13:31:24 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 177
# [13:31:24 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:31:24 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.11318173786486489
# [13:31:24 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 19.512821499501978,
#  'CO2': 0.476345259919714,
#  'H2': 24.320693354957992,
#  'H2O': 2.706940621044774,
#  'N2': 1.141854299521027,
#  'O2': 1.0324938813897587e-09}
# [13:31:24 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 178
# [13:31:24 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:31:24 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.28141608115324074
# [13:31:24 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 13.085281221016823,
#  'CO2': 0.16596010790182392,
#  'H2': 91.19222960920771,
#  'H2O': 5.273263619676968,
#  'N2': 0.4833265886630878,
#  'O2': 2.786924669555601e-10}
# [13:31:24 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 179
# [13:31:25 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:31:25 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.10746182642587013
# [13:31:25 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 10.63390984061206,
#  'CO2': 0.14926709759094714,
#  'H2': 10.77351655483857,
#  'H2O': 0.6894925831327152,
#  'N2': 1.248565277762758,
#  'O2': 3.4137063748104203e-10}
# [13:31:25 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 180
# [13:31:25 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:31:25 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.0936978727333382
# [13:31:25 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 18.086917941959065,
#  'CO2': 26.087460455225575,
#  'H2': 0.2249126980485759,
#  'H2O': 1.4790478071962945,
#  'N2': 2.752992593961531,
#  'O2': 3.604279031007786e-06}
# [13:31:25 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 181
# [13:31:25 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:31:25 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.26867381044394834
# [13:31:25 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 27.284314936683593,
#  'CO2': 0.3578113284464698,
#  'H2': 200.4284744995374,
#  'H2O': 11.983990457491775,
#  'N2': 0.4699126445869104,
#  'O2': 2.979655117808516e-10}
# [13:31:25 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 182
# [13:31:26 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:31:26 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.11173926937992415
# [13:31:26 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 97.80222046915155,
#  'CO2': 136.8752610365765,
#  'H2': 0.7030357939351453,
#  'H2O': 4.485952631900401,
#  'N2': 2.796296967595857,
#  'O2': 3.3934107016916182e-06}
# [13:31:26 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 183
# [13:31:26 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:31:26 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.025555769831480744
# [13:31:26 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 11.608239713361023,
#  'CO2': 38.065855617763994,
#  'H2': 0.12421316405162006,
#  'H2O': 1.857110963225108,
#  'N2': 2.9380832355174937,
#  'O2': 1.8630409058416195e-05}
# [13:31:26 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 184
# [13:31:26 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:31:26 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.13279627484098633
# [13:31:26 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 144.470321105777,
#  'CO2': 7.645976242252073,
#  'H2': 85.50056218452845,
#  'H2O': 20.63118994550956,
#  'N2': 1.4978812165313304,
#  'O2': 4.852801716117443e-09}
# [13:31:26 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 185
# [13:31:27 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:31:27 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.29438258963026254
# [13:31:27 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 12.061184999667427,
#  'CO2': 226.16888631578618,
#  'H2': 0.19845143408287616,
#  'H2O': 16.966729003883362,
#  'N2': 3.1192416981082967,
#  'O2': 0.0006092137480288077}
# [13:31:27 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 186
# [13:31:27 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:31:27 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.05126418338857317
# [13:31:27 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 70.76891480663149,
#  'CO2': 183.77597816004172,
#  'H2': 0.94209138406427,
#  'H2O': 11.154246553854017,
#  'N2': 2.9130183213338627,
#  'O2': 1.1683591070133818e-05}
# [13:31:27 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 187
# [13:31:27 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:31:27 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.15255596926605205
# [13:31:27 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 7.764632880617282,
#  'CO2': 61.095734717974665,
#  'H2': 0.09940230583732668,
#  'H2O': 3.5660499743474374,
#  'N2': 3.0562463891071796,
#  'O2': 0.00010726643931801708}
# [13:31:27 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 188
# [13:31:28 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:31:28 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.17621341535164203
# [13:31:28 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 3.083139926479336,
#  'CO2': 24.838969830165226,
#  'H2': 0.031304711242176965,
#  'H2O': 1.1498761012402945,
#  'N2': 3.0251406602776907,
#  'O2': 0.0001124513370106793}
# [13:31:28 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 189
# [13:31:28 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:31:28 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.20112952587823107
# [13:31:28 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 325.22913121348364,
#  'CO2': 50.98447336164052,
#  'H2': 21.820917968413458,
#  'H2O': 15.596333611429417,
#  'N2': 2.177436493010511,
#  'O2': 4.257757587319525e-08}
# [13:31:28 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 190
# [13:31:28 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:31:28 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.06657187206041207
# [13:31:28 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 54.675429713723396,
#  'CO2': 234.68790885701014,
#  'H2': 0.276760841058305,
#  'H2O': 5.416317981788762,
#  'N2': 3.053607387505693,
#  'O2': 3.192132830056324e-05}
# [13:31:28 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 191
# [13:31:28 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:31:28 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.1713446767072965
# [13:31:28 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 45.99916474212101,
#  'CO2': 5.937250772059355,
#  'H2': 2.713543354839971,
#  'H2O': 1.596883423318136,
#  'N2': 2.1716856059274203,
#  'O2': 2.88638878165547e-08}
# [13:31:28 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 192
# [13:31:29 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:31:29 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.1907724812573722
# [13:31:29 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 31.83484503315983,
#  'CO2': 272.73466093492726,
#  'H2': 0.09859182394776306,
#  'H2O': 3.851053007776312,
#  'N2': 3.15768184573786,
#  'O2': 0.00012716251915247738}
# [13:31:29 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 193
# [13:31:29 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:31:29 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.17373675953819762
# [13:31:29 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 153.5485161935328,
#  'CO2': 31.56856076698215,
#  'H2': 1.8603983876172152,
#  'H2O': 1.743878060843656,
#  'N2': 2.3295278087825357,
#  'O2': 7.323222868514994e-08}
# [13:31:29 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 194
# [13:31:30 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:31:30 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.08150094203099081
# [13:31:30 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 116.40288034643548,
#  'CO2': 251.74654746072352,
#  'H2': 1.6981714555688063,
#  'H2O': 16.744891348444455,
#  'N2': 2.870029726460742,
#  'O2': 8.103703205657878e-06}
# [13:31:30 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 195
# [13:31:30 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:31:30 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.11207939669730997
# [13:31:30 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 93.13252105651486,
#  'CO2': 132.75447178223777,
#  'H2': 0.3684333891512221,
#  'H2O': 2.394461077518324,
#  'N2': 2.8153558329799706,
#  'O2': 3.5202988498518233e-06}
# [13:31:30 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 196
# [13:31:30 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:31:30 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.10765856339351668
# [13:31:30 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 42.53463728171999,
#  'CO2': 55.742316326332286,
#  'H2': 0.13058037272042466,
#  'H2O': 0.7802273729967416,
#  'N2': 2.78712188591199,
#  'O2': 2.97555847874288e-06}
# [13:31:30 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 197
# [13:31:31 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:31:31 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.20501233138649091
# [13:31:31 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 129.2679820639334,
#  'CO2': 48.427605634848895,
#  'H2': 6.6985910911230215,
#  'H2O': 11.441593035855378,
#  'N2': 2.3409115231524007,
#  'O2': 2.431576793083486e-07}
# [13:31:31 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 198
# [13:31:31 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:31:31 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.1343597887322836
# [13:31:31 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 464.44023145211526,
#  'CO2': 16.729288838927893,
#  'H2': 133.64920253869522,
#  'H2O': 21.949014199966467,
#  'N2': 1.7617123396581404,
#  'O2': 2.2479115958243435e-09}
# [13:31:31 - atmodeller.interior_atmosphere - INFO     ] - Solving system number 199
# [13:31:31 - atmodeller.interior_atmosphere - INFO     ] - The solution converged.
# [13:31:31 - atmodeller.interior_atmosphere - INFO     ] - InitialConditionRegressor: RMSE (actual vs initial) = 0.36951464460623107
# [13:31:31 - atmodeller.initial_condition   - INFO     ] - InitialConditionRegressor: Partial fit (150, 200)
# [13:31:31 - atmodeller.interior_atmosphere - INFO     ] - {'CO': 9.41838607202564,
#  'CO2': 209.5835336643913,
#  'H2': 0.033365514722854324,
#  'H2O': 3.3851623324402382,
#  'N2': 3.2164769259578305,
#  'O2': 0.0008579169999114588}

# %% [markdown]
# If you compare the log output for the two MC runs, you will see in the second MC example that the initial condition re-trained itself after 100 samples had been generated and then partially retrained itself every 50 samples. This keeps the RMSE between the initial guess and actual solution to a smaller value than simply guessing a constant initial condition. Also, fit = True allows you to train an initial condition on a similar but not identical model (for example, different solubility laws or gas equations of states), where once enough samples have been generated you would prefer to only use the new model to generate new estimates (since the behavior of the new model and the previous similar-but-not-the-same model will diverge).
